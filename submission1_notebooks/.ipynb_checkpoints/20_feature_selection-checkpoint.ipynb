# %% [markdown]
# # Feature Selection
#
#
# Add some text here describing the feature selection process and results.

# %% [markdown]
# # Table of Contents
#
# Take this as an example for a Table of Contents for your notebook.
# We have to fix all the names and sections according to what we actually do in the notebook.
#
# <a class="anchor" id="top"></a>
#
# ** **
#
# 1. [Importing Libraries & Data](#1.-Importing-Libraries-&-Data) <br><br>
#
# 2. [Exploratory Data Analysis](#2.-Exploratory-Data-Analysis)
#
#    2.1 [Incoherencies](#2.1-Incoherencies) <br>
#
#    &emsp; 2.1.1 [Address Identified Incoherencies](#2.1.1-Address-Identified-Incoherencies) <br><br>
#
# 3. [Data Cleaning & Preprocessing](#3.-Data-Cleaning-&-Preprocessing)
#
#    3.1 [Duplicates](#3.1-Duplicates) <br>
#
#    3.2 [Feature Engineering](#3.2-Feature-Engineering) <br>
#
#    &emsp; 3.2.1 [Data Type Conversions](#3.2.1-Data-Type-Conversions) <br>
#
#    &emsp; 3.2.2 [Encoding](#3.2.2-Encoding) <br>
#
#    &emsp; 3.2.3 [Other Transformations](#3.2.3-Other-Transformations) <br>
#
#    &emsp; 3.2.4 [Unique Feature-Pair Analysis](#3.2.4-Unique-Feature-Pair-Analysis) <br>
#
#    3.3 [Train-Test Split](#3.3-Train-Test-Split) <br>
#
#    3.4 [Missing Values](#3.4-Missing-Values) <br>
#
#    3.5 [Outliers](#3.5-Outliers) <br>
#
#    3.6 [Visualisations](#3.6-Visualisations) <br><br>

# %%
# ======================================================
# 🧩 20 — Feature Selection
# ======================================================
"""
Goal:
We will now start the feature selection process on the fully encoded and scaled data.
In this step, we simply load the processed datasets that were saved in the previous notebook (12_data_imputation_and_encoding.ipynb).

Loaded datasets:
- X_train, y_train
- X_val, y_val
- X_test
"""

# --- Imports ---
import os
import pandas as pd

# --- Define paths ---
data_dir = "../data/"
encoded_dir = os.path.join(data_dir, "encoded_data")

# --- Load encoded & scaled datasets ---
X_train = pd.read_csv(os.path.join(encoded_dir, "12_X_train.csv"))
y_train = pd.read_csv(os.path.join(encoded_dir, "12_y_train.csv")).squeeze()

X_val = pd.read_csv(os.path.join(encoded_dir, "12_X_val.csv"))
y_val = pd.read_csv(os.path.join(encoded_dir, "12_y_val.csv")).squeeze()

X_test = pd.read_csv(os.path.join(encoded_dir, "12_X_test.csv"))

# --- Sanity checks ---
print("✅ Encoded datasets successfully loaded!")
print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"X_val shape:   {X_val.shape}")
print(f"y_val shape:   {y_val.shape}")
print(f"X_test shape:  {X_test.shape}")
# Out:
# ✅ Encoded datasets successfully loaded!
# X_train shape: (56979, 20)
# y_train shape: (56979,)
# X_val shape:   (18994, 20)
# y_val shape:   (18994,)
# X_test shape:  (32567, 20)

# %%
# ======================================================
# Step 1: Sanity-Checks & Feature Lists
# ======================================================
import numpy as np
import pandas as pd
import re

def has_missing(name, X):
    n = int(X.isna().sum().sum())
    print(f"[{name}] total NaNs: {n}")
    return n

_ = has_missing("X_train", X_train)
_ = has_missing("X_val",   X_val)
_ = has_missing("X_test",  X_test)

# Column consistency
assert list(X_train.columns) == list(X_val.columns) == list(X_test.columns), "Columns inconsistent between splits!"

# Determine feature types heuristically
all_cols = X_train.columns.tolist()

# One-hot: detect columns typically created by OHE (0/1) and name patterns like transmission_*, fuelType_*
binary_mask = (X_train.nunique(dropna=False) <= 2) & (X_train.isin([0,1]).all())  # actual 0/1
ohe_like_cols = X_train.columns[binary_mask].tolist()

# Target-encoded columns (if named that way)
te_cols = [c for c in ["Brand", "model"] if c in X_train.columns]

# Continuous numeric (without OHE, without TE)
cont_num_cols = [c for c in all_cols if c not in set(ohe_like_cols + te_cols)]

print(f"#features total: {len(all_cols)}")
print(f"#OHE-like (binary 0/1): {len(ohe_like_cols)} → {ohe_like_cols[:10]}{' ...' if len(ohe_like_cols)>10 else ''}")
print(f"#Target-encoded: {len(te_cols)} → {te_cols}")
print(f"#Continuous numeric: {len(cont_num_cols)} → {cont_num_cols[:10]}{' ...' if len(cont_num_cols)>10 else ''}")
# Out:
# [X_train] total NaNs: 0
# [X_val] total NaNs: 0
# [X_test] total NaNs: 0
# #features total: 20
# #OHE-like (binary 0/1): 9 → ['hasDamage', 'transmission_automatic', 'transmission_other', 'transmission_semi-auto', 'transmission_unknown', 'fuelType_diesel', 'fuelType_electric', 'fuelType_hybrid', 'fuelType_other']
# #Target-encoded: 2 → ['Brand', 'model']
# #Continuous numeric: 9 → ['year', 'mileage', 'tax', 'mpg', 'engineSize', 'paintQuality%', 'previousOwners', 'transmission_manual', 'fuelType_petrol']

# %%
# ======================================================
# Step 2: Remove Constant (and optionally Quasi-Constant) Features
# ======================================================
def drop_constant_features(X_tr, X_va, X_te, quasi_threshold=None):
    # Constant
    constant_cols = [c for c in X_tr.columns if X_tr[c].nunique(dropna=False) <= 1]
    
    # Quasi-constant (optional)
    quasi_cols = []
    if quasi_threshold is not None:
        for c in X_tr.columns:
            top_freq = X_tr[c].value_counts(normalize=True, dropna=False).iloc[0]
            if top_freq >= quasi_threshold and c not in constant_cols:
                quasi_cols.append(c)
    
    drop_cols = sorted(set(constant_cols + quasi_cols))
    if drop_cols:
        X_tr = X_tr.drop(columns=drop_cols)
        X_va = X_va.drop(columns=drop_cols)
        X_te = X_te.drop(columns=drop_cols)
    return X_tr, X_va, X_te, constant_cols, quasi_cols

X_train_fs, X_val_fs, X_test_fs, const_cols, quasi_cols = drop_constant_features(
    X_train.copy(), X_val.copy(), X_test.copy(),
    quasi_threshold=None  # set later to e.g. 0.995 if desired
)

print(f"Removed constant cols: {len(const_cols)} → {const_cols}")
print(f"Removed quasi-constant cols: {len(quasi_cols)} → {quasi_cols}")
print("Shapes:", X_train_fs.shape, X_val_fs.shape, X_test_fs.shape)
# Out:
# Removed constant cols: 1 → ['hasDamage']
# Removed quasi-constant cols: 0 → []
# Shapes: (56979, 19) (18994, 19) (32567, 19)

# %%
# ======================================================
# Step 3: Pearson Correlation with Target (Top signals)
# ======================================================
def feature_target_corr(X, y, top_k=25):
    corrs = {}
    for c in X.columns:
        try:
            corrs[c] = np.corrcoef(X[c].astype(float), y.astype(float))[0,1]
        except Exception:
            # If it cannot be converted (should not happen after encoding/scaling)
            continue
    corr_s = pd.Series(corrs).dropna()
    corr_abs_sorted = corr_s.abs().sort_values(ascending=False)
    top = corr_abs_sorted.head(top_k).index
    out = pd.DataFrame({
        "corr": corr_s[top],
        "abs_corr": corr_abs_sorted.head(top_k)
    }).sort_values("abs_corr", ascending=False)
    return out

corr_top = feature_target_corr(X_train_fs, y_train, top_k=25)
print("Top features by |Pearson corr| with price:")
display(corr_top)
# Out:
# Top features by |Pearson corr| with price:
#                             corr  abs_corr
# model                   0.700386  0.700386
# engineSize              0.604024  0.604024
# Brand                   0.530182  0.530182
# transmission_manual    -0.528158  0.528158
# year                    0.471945  0.471945
# transmission_semi-auto  0.404355  0.404355
# mileage                -0.399715  0.399715
# tax                     0.285388  0.285388
# mpg                    -0.272542  0.272542
# transmission_automatic  0.235704  0.235704
# fuelType_petrol        -0.205892  0.205892
# fuelType_diesel         0.193123  0.193123
# fuelType_hybrid         0.044149  0.044149
# previousOwners          0.002636  0.002636
# fuelType_other         -0.002372  0.002372
# paintQuality%          -0.001352  0.001352
# fuelType_electric      -0.001062  0.001062
# transmission_unknown    0.000619  0.000619
# transmission_other      0.000046  0.000046

# %%
# ======================================================
# Step 4: Highly Correlated Feature Pairs (|r| > 0.95)
# ======================================================
threshold = 0.95
X_num = X_train_fs.select_dtypes(include=["number"]).copy()

corr_mat = X_num.corr().abs()
upper = corr_mat.where(np.triu(np.ones(corr_mat.shape), k=1).astype(bool))
pairs = [(c1, c2, upper.loc[c1, c2]) for c1 in upper.columns for c2 in upper.columns if c1!=c2 and not pd.isna(upper.loc[c1, c2]) and upper.loc[c1, c2] > threshold]

print(f"Found {len(pairs)} highly correlated pairs (>|{threshold}|).")
pairs_sorted = sorted(pairs, key=lambda x: x[2], reverse=True)
display(pd.DataFrame(pairs_sorted, columns=["feat_1","feat_2","abs_corr"]).head(20))

# Suggestion: drop candidates (keep the feature in each pair with higher |corr(price)|)
# Uses the target correlations computed in Step 3 (recompute if missing)
if 'corr_top' in globals():
    target_corr = corr_top["abs_corr"]
else:
    tmp = feature_target_corr(X_train_fs, y_train, top_k=len(X_train_fs.columns))
    target_corr = tmp["abs_corr"]

target_corr_full = target_corr.reindex(X_train_fs.columns).fillna(0)

drop_suggestions = []
for f1, f2, _ in pairs_sorted:
    c1 = target_corr_full.get(f1, 0)
    c2 = target_corr_full.get(f2, 0)
    # drop the one with the lower target correlation
    drop_suggestions.append((f1 if c1 < c2 else f2, f1, f2, c1, c2))

drop_df = pd.DataFrame(drop_suggestions, columns=["drop_candidate","feat_1","feat_2","|corr(price)|_feat_1","|corr(price)|_feat_2"])
print("Suggested drops (keep the counterpart with higher |corr(price)|):")
display(drop_df.head(20))
# Out:
# Found 0 highly correlated pairs (>|0.95|).
# Empty DataFrame
# Columns: [feat_1, feat_2, abs_corr]
# Index: []
# Suggested drops (keep the counterpart with higher |corr(price)|):
# Empty DataFrame
# Columns: [drop_candidate, feat_1, feat_2, |corr(price)|_feat_1, |corr(price)|_feat_2]
# Index: []

# %%
# ======================================================
# Step 5: Drop Highly Correlated / Redundant Features
# ======================================================
"""
We remove redundant features that show very high inter-feature correlation (|r| > 0.95).
Keeping both would introduce multicollinearity and reduce model interpretability.
The feature with lower |corr(price)| was dropped per pair.
"""

# Take all recommended drop candidates from Step 4
drop_candidates = drop_df["drop_candidate"].unique().tolist()

print(f"Preparing to drop {len(drop_candidates)} redundant features...")
X_train_sel = X_train_fs.drop(columns=drop_candidates, errors="ignore")
X_val_sel   = X_val_fs.drop(columns=drop_candidates, errors="ignore")
X_test_sel  = X_test_fs.drop(columns=drop_candidates, errors="ignore")

print("✅ After dropping redundant features:")
print(f"X_train: {X_train_sel.shape}, X_val: {X_val_sel.shape}, X_test: {X_test_sel.shape}")
# Out:
# Preparing to drop 0 redundant features...
# ✅ After dropping redundant features:
# X_train: (56979, 19), X_val: (18994, 19), X_test: (32567, 19)

# %%
# ======================================================
# Step 6: Univariate Feature Importance — Mutual Information
# ======================================================
"""
Mutual Information (MI) quantifies how much information each feature provides about the target.
Unlike correlation, MI can capture nonlinear dependencies.
"""

from sklearn.feature_selection import mutual_info_regression
import numpy as np
import pandas as pd

# Use only numeric columns (all should be numeric after encoding)
X_train_num = X_train_sel.select_dtypes(include=["number"]).copy()

# Compute MI scores
mi_scores = mutual_info_regression(X_train_num, y_train, random_state=42)
mi_series = pd.Series(mi_scores, index=X_train_num.columns).sort_values(ascending=False)

# Show top features
print("Top 25 features by Mutual Information with target (price):")
display(mi_series.head(25).to_frame("mutual_info"))

# Optional: show histogram/distribution
import matplotlib.pyplot as plt
plt.figure(figsize=(10,4))
mi_series.head(25).plot(kind="barh")
plt.title("Top 25 Features by Mutual Information with Price")
plt.xlabel("Mutual Information Score")
plt.gca().invert_yaxis()
plt.show()
# Out:
# Top 25 features by Mutual Information with target (price):
#                         mutual_info
# model                      0.699152
# engineSize                 0.387532
# mpg                        0.375552
# year                       0.334757
# Brand                      0.323093
# mileage                    0.318609
# transmission_manual        0.211083
# tax                        0.178385
# transmission_semi-auto     0.122818
# fuelType_petrol            0.063511
# transmission_automatic     0.060421
# fuelType_diesel            0.054815
# fuelType_hybrid            0.015157
# previousOwners             0.001759
# transmission_other         0.000969
# paintQuality%              0.000073
# transmission_unknown       0.000000
# fuelType_electric          0.000000
# fuelType_other             0.000000

# %%
# ======================================================
# Step 7: Model-based Feature Importance (Random Forest)
# ======================================================
"""
We use a tree-based model (RandomForestRegressor) to estimate feature importances.
Tree-based methods can capture nonlinear interactions and rank the most predictive features.
"""

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 1️⃣ Train the model (training data only)
rf = RandomForestRegressor(
    n_estimators=300,
    max_depth=None,
    random_state=42,
    n_jobs=-1
)
rf.fit(X_train_sel, y_train)

# 2️⃣ Wichtigkeiten extrahieren
importances = rf.feature_importances_
feat_importances = pd.Series(importances, index=X_train_sel.columns).sort_values(ascending=False)

# 3️⃣ Performance check (compatible RMSE calculation)
y_val_pred = rf.predict(X_val_sel)
mse = mean_squared_error(y_val, y_val_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_val, y_val_pred)

print(f"Validation RMSE: {rmse:,.2f}")
print(f"Validation R²:   {r2:.4f}")

# 4️⃣ Show top features
print("Top 25 features by model-based importance:")
display(feat_importances.head(25).to_frame("importance"))

# 5️⃣ Visualization
plt.figure(figsize=(10,5))
feat_importances.head(25).plot(kind="barh")
plt.title("Top 25 Features by Random Forest Importance")
plt.xlabel("Importance")
plt.gca().invert_yaxis()
plt.show()
# Out:
# Validation RMSE: 2,294.34
# Validation R²:   0.9429
# Top 25 features by model-based importance:
#                           importance
# model                   4.397090e-01
# engineSize              1.829823e-01
# mileage                 1.464317e-01
# year                    1.201804e-01
# mpg                     5.846390e-02
# Brand                   1.199601e-02
# tax                     1.161368e-02
# paintQuality%           1.011549e-02
# transmission_manual     6.511731e-03
# previousOwners          4.229096e-03
# fuelType_diesel         2.179729e-03
# fuelType_petrol         1.823696e-03
# transmission_semi-auto  1.316779e-03
# transmission_automatic  1.160794e-03
# fuelType_hybrid         1.116592e-03
# transmission_unknown    1.373387e-04
# fuelType_other          2.864591e-05
# transmission_other      2.374403e-06
# fuelType_electric       6.337699e-07

# %%
# ======================================================
# Step 8: Combine All Methods & Select Final Features
# ======================================================
"""
We combine results from:
- Pearson correlation with target
- Mutual Information (nonlinear relevance)
- Random Forest model-based importances

Then we select the most informative features across methods
and save the final feature list for later model training.
"""

import pandas as pd
import numpy as np
import os
import json

# --- 1️⃣ Normalize all scores between 0 and 1 ---
# Pearson correlation (abs)
pearson_scores = corr_top["abs_corr"]
pearson_scores = pearson_scores / pearson_scores.max()

# Mutual Information (already non-negative)
mi_scores_norm = mi_series / mi_series.max()

# Model-based importances
rf_scores_norm = feat_importances / feat_importances.max()

# --- 2️⃣ Combine into one DataFrame ---
score_df = pd.concat([pearson_scores, mi_scores_norm, rf_scores_norm], axis=1)
score_df.columns = ["pearson_abs_corr", "mutual_info", "rf_importance"]

# Set missing values (e.g., a feature absent in a method) to 0
score_df = score_df.fillna(0)

# --- 3️⃣ Compute overall score (weighted average, adjustable) ---
score_df["combined_score"] = (
    0.3 * score_df["pearson_abs_corr"] +
    0.3 * score_df["mutual_info"] +
    0.4 * score_df["rf_importance"]
)

# --- 4️⃣ Sort by overall score ---
score_df = score_df.sort_values("combined_score", ascending=False)
print("Top 25 combined feature scores:")
display(score_df.head(25))

# --- 5️⃣ Feature selection (threshold or fixed count) ---
# You can adjust this dynamically:
top_k = 10  # e.g. keep the top 10 features
selected_features = score_df.head(top_k).index.tolist()

print(f"✅ Selected {len(selected_features)} final features:")
print(selected_features[:15], "..." if len(selected_features) > 15 else "")

# --- 6️⃣ Save final feature list ---
output_dir = os.path.join(data_dir, "feature_selection")
os.makedirs(output_dir, exist_ok=True)

selected_path = os.path.join(output_dir, "20_selected_features.json")
with open(selected_path, "w") as f:
    json.dump(selected_features, f, indent=2)

print(f"💾 Saved final feature list → {selected_path}")
# Out:
# Top 25 combined feature scores:
#                         pearson_abs_corr  mutual_info  rf_importance  \
# model                           1.000000     1.000000       1.000000
# engineSize                      0.862416     0.554289       0.416144
# year                            0.673835     0.478804       0.273318
# mileage                         0.570707     0.455708       0.333020
# Brand                           0.756986     0.462122       0.027282
# mpg                             0.389131     0.537154       0.132960
# transmission_manual             0.754096     0.301913       0.014809
# transmission_semi-auto          0.577331     0.175668       0.002995
# tax                             0.407472     0.255146       0.026412
# transmission_automatic          0.336534     0.086420       0.002640
# fuelType_petrol                 0.293969     0.090839       0.004148
# fuelType_diesel                 0.275738     0.078402       0.004957
# ...
