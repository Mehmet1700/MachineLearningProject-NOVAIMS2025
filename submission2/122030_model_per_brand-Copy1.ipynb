# %% [markdown]
# # 2030 – Model Encoding, Feature Selection, modeling and valuation for each brand
#
# ## Notebook Overview
# This notebook shows our approach of spliting into brand specific models.
#
# - Inputs: `11_processed_train_data.csv`, `11_processed_test_data.csv`.
# - Outputs: `30_submission_YYYYMMDD_HHMM_rf.csv`, `30_submission_YYYYMMDD_HHMM_etr.csv`, `30_submission_YYYYMMDD_HHMM_hgbr.csv` and `30_submission_YYYYMMDD_HHMM_hybrid.csv` in `../data/submissions/`.
#
# ### Preprocessing
# This notebook first splits the data into validation and training stratified by brand (important for later). It then imputes the categorical missing values. After that it splits the data set into different brands to from now on do steps only for the specific brand. In the next step we impute the numerical missing values. After that we both one hot and target encode the categorical features. We decide not to scale our data, since it is useless for the models we use here.
#
# ### Feature Selection
# We use filter (variance, correlation) and wrapper (RFE) methods, selecting features based on validation performance while avoiding leakage.
#
# ### Models
# For the Models we use a Random Forest Regressor, an Extra Tree Regressor and a Hist Gradient Boosting Regressor. For all of them we use parameter grid search. At the end we also combine Extra Tree Regressor and a Hist Gradient Boosting Regressor (with weights), which is our best model we got in this project.
#
# ### Evaluation
#
# TBD
#
# Note: All model selection uses the validation split; only the final chosen model is trained on train+val before generating test predictions.

# %% [markdown]
# # Table of Contents
#
# <a id="top"></a>
#
# - [Notebook Overview](#notebook-overview)
# - [1. Import Libraries](#sec-1-imports)
# - [1. Functions](#sec-1-imports)
# - [2. Load Dataset](#sec-2-load)
# - [3. Imputation Strategies](#sec-3-sanity)
# - [Intermediate step: Split Brands](#intermediate-step-split-brands)
# - [3.2 Numerical Imputation](#3-2-numerical-imputation)
# - [5. Feature Engineering](#5-feature-engineering)
# - [6. Scaling](#6-scaling)
# - [7. Encoding](#7-encoding)
# - [8. Feature Selection](#sec-4-filter)
# - [9. Models](#9-models)
# - [9.2 Extra Trees Regressor](#9-2-extra-trees-regressor)
# - [9.3 Hist Gradient Boosting Regressor](#9-3-hist-gradient-boosting-regressor)
# - [9.4 Hybrid Model (Extra Tree Regressor * 0,6 + High Gradient Boosting * 0,4)](#9-4-hybrid-model-extra-tree-regressor-0-6-high-gradient-boosting-0-4)

# %% [markdown]
# <a id="sec-1-imports"></a>
# ## 1. Import Libraries

# %% [markdown]
# All needed imports sorted by library.

# %%
# Standard library
import json
import math
import os
import re
import warnings
from datetime import datetime
from pathlib import Path

# third-party
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from dotenv import load_dotenv

# sklearn: model selection / metrics
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.model_selection import ParameterGrid, train_test_split

# sklearn: preprocessing / pipeline
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, RobustScaler, TargetEncoder

# sklearn: models
from sklearn.ensemble import ExtraTreesRegressor, HistGradientBoostingRegressor, RandomForestClassifier, RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor

# sklearn: feature selection / base / inspection
from sklearn.base import BaseEstimator, TransformerMixin, clone
from sklearn.inspection import permutation_importance

# sklearn: evaluation
from sklearn.metrics import mean_absolute_error, median_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# <a id="sec-1-imports"></a>
# ## 1. Functions

# %%
# Function to summarize missing values for a given dataset
def missing_report(X: pd.DataFrame, name: str) -> pd.DataFrame:
    """Generate and display a simple missing-value report for a DataFrame.

    Parameters
    ----------
    X : pd.DataFrame
        Input data for which missing values should be summarized.
    name : str
        A label used in printed output to identify this dataset (e.g. 'train', 'test').

    Returns
    -------
    pd.DataFrame
        A DataFrame with two columns:
        - 'n_missing': absolute number of missing values per column
        - 'pct_missing': percentage of missing values per column

        If no missing values are found, an empty DataFrame with the same columns is returned.
    """
    # Count missing values per column
    mv = X.isna().sum()
    # Keep only columns with at least one missing value, sorted by count
    mv = mv[mv > 0].sort_values(ascending=False)

    # If there are no missing values, print a short message and return an empty report
    if mv.empty:
        print(f"[{name}] No missing values found. (n_rows={len(X)})")
        return pd.DataFrame(columns=["n_missing", "pct_missing"])

    # Compute percentage of missing values per column (rounded to two decimals)
    pct = (mv / len(X) * 100).round(2)

    # Combine counts and percentages into a single DataFrame
    report = pd.DataFrame({"n_missing": mv, "pct_missing": pct})

    # Print and display the report for quick inspection
    print(f"[{name}] Missing Values (n_rows={len(X)}):")
    display(report)

    return report

# %%
# Function to build an imputation pipeline template based on available features
def make_template_for(features):
    """Create an imputation pipeline tailored to the given feature set.

    Parameters
    ----------
    features : list-like
        Collection of feature names present in the dataset.

    Returns
    -------
    sklearn.Pipeline
        An imputation pipeline configured with:
        - low-cardinality categorical columns (Brand, fuelType, transmission), if present
        - high-cardinality categorical columns (model), if present
    """
    # Select low-cardinality categorical columns that are actually present
    low_card = [c for c in ["Brand", "fuelType", "transmission"] if c in features]
    # Select high-cardinality categorical columns that are actually present
    high_card = [c for c in ["model"] if c in features]

    # Create a pipeline that knows how to impute low- and high-card categorical features
    return create_imputation_pipeline(low_card_cols=low_card, high_card_cols=high_card)

# %%
# Function to apply all fitted imputers in a consistent order
def apply_imputers(X):
    """Apply all pre-fitted imputers to the input data `X` in sequence.

    This function assumes that the global imputers (trans_imputer, fuel_imputer,
    brand_imputer, model_imputer) have already been fitted on the training data.
    It returns the transformed feature matrix with missing values imputed.
    """
    # Apply transmission imputer
    X = trans_imputer.transform(X)
    # Apply fuel type imputer
    X = fuel_imputer.transform(X)
    # Apply brand imputer
    X = brand_imputer.transform(X)
    # Apply model imputer
    X = model_imputer.transform(X)
    return X

# %%
# Function to drop low-variance features (below a given threshold)
def drop_low_variance_features(x, threshold):
    """Remove columns whose variance is below `threshold`.
    Returns the reduced frame and the list of dropped features for consistency across splits.
    """
    # Calculate the variance of each feature
    variances = x.var()
    # Identify features with variance below the threshold
    low_variance_features = variances[variances < threshold].index
    # Drop low-variance features
    x = x.drop(columns=low_variance_features)
    return x, low_variance_features

# %% [markdown]
# <a id="sec-2-load"></a>
# ## 2. Load Dataset

# %% [markdown]
# Load the mapped and normalized datasets produced in notebook 11 and confirm shapes before proceeding. <br>

# %%
# Load the data paths
data_dir = "../data/"

# Load automatically the latest folder based on date pattern
latest_folder = sorted(os.listdir(os.path.join(data_dir, "processed_data")))[-1]

# Load the raw data into a pandas dataframe
df = pd.read_csv(os.path.join(data_dir, f"processed_data/{latest_folder}/11_processed_train_data.csv"))
x_test = pd.read_csv(os.path.join(data_dir, f"processed_data/{latest_folder}/11_processed_test_data.csv"))

# put carID as Index
df.set_index("carID", inplace=True)
x_test.set_index("carID", inplace=True)

print("Loaded shape:", df.shape)
display(df.head(3))

print("Loaded test shape:", x_test.shape)
display(x_test.head(3))
# Out:
# Loaded shape: (74467, 12)
#             Brand  model    year    price transmission  mileage fuelType  \
# carID
# 69512  Volkswagen   Golf  2016.0  22290.0    Semi-Auto  28421.0   Petrol
# 53000      Toyota  Yaris  2019.0  13790.0       Manual   4589.0   Petrol
# 6366         Audi     Q2  2019.0  24990.0    Semi-Auto   3624.0   Petrol
#
#          tax        mpg  engineSize  previousOwners  hasDamage
# carID
# 69512    NaN  11.417268         2.0             4.0        0.0
# 53000  145.0  47.900000         1.5             1.0        0.0
# 6366   145.0  40.900000         1.5             4.0        0.0
# Loaded test shape: (32567, 11)
#              Brand     model    year transmission  mileage fuelType    tax  \
# carID
# 89856      Hyundai       i30     NaN    Automatic  30700.0   Petrol  205.0
# 106581  Volkswagen    Tiguan  2017.0    Semi-Auto      NaN   Petrol  150.0
# 80886          BMW  2 Series  2016.0    Automatic  36792.0   Petrol  125.0
#
#          mpg  engineSize  previousOwners  hasDamage
# carID
# 89856   41.5         1.6             3.0        0.0
# 106581  38.2         2.0             2.0        0.0
# 80886   51.4         1.5             2.0        0.0

# %% [markdown]
# In the next cell we split our data into train and validation data. We use an 85/15 train–validation split, stratified by Brand.
# Because the competition already holds out 20% of the full dataset as test data, we wanted to keep the validation size small so that we don't lose too much training data.

# %%
# Separate features and target from the training data
x = df.drop(columns=["price"])
y = df["price"]

# Split df (80% of total data) into training and validation
x = df.drop(columns=["price"])
y = df["price"]

# only for stratify
brand_strat = x["Brand"].fillna("Unknown")   # or "UNK"

x_train, x_val, y_train, y_val = train_test_split(
    x,
    y,
    test_size=0.15,
    random_state=42,
    stratify=brand_strat # it trys to split the brands equaly --> good so that we have around the same percentage splits into val and train for each brand
)

print(f"x_train shape: {x_train.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"x_val shape:   {x_val.shape}")
print(f"y_val shape:   {y_val.shape}")
print(f"x_test shape:  {x_test.shape}")
# Out:
# x_train shape: (63296, 11)
# y_train shape: (63296,)
# x_val shape:   (11171, 11)
# y_val shape:   (11171,)
# x_test shape:  (32567, 11)

# %% [markdown]
# In the next cell we check what missing values for which type of variables we will have to impute.

# %%
# Reports for the splits
missing_report(x_train, "x_train")
missing_report(x_val,   "x_val")
missing_report(x_test,  "x_test")

# check which columns are categorical and which numerical
numeric_cols = x_train.select_dtypes(include=["number"]).columns.tolist()
categorical_cols = x_train.select_dtypes(include=["object", "category", "bool"]).columns.tolist()

print(f"#numeric_cols: {len(numeric_cols)} → {numeric_cols[:10]}{' ...' if len(numeric_cols) > 10 else ''}")
print(f"#categorical_cols: {len(categorical_cols)} → {categorical_cols[:10]}{' ...' if len(categorical_cols) > 10 else ''}")
# Out:
# [x_train] Missing Values (n_rows=63296):
#                 n_missing  pct_missing
# mpg                  7653        12.09
# tax                  6892        10.89
# transmission         1887         2.98
# engineSize           1742         2.75
# previousOwners       1596         2.52
# mileage              1525         2.41
# model                1445         2.28
# hasDamage            1274         2.01
# fuelType             1249         1.97
# year                  310         0.49
# Brand                  37         0.06
# [x_val] Missing Values (n_rows=11171):
#                 n_missing  pct_missing
# mpg                  1351        12.09
# tax                  1216        10.89
# transmission          331         2.96
# engineSize            313         2.80
# previousOwners        292         2.61
# mileage               276         2.47
# model                 259         2.32
# hasDamage             247         2.21
# fuelType              230         2.06
# year                   48         0.43
# Brand                   7         0.06
# [x_test] Missing Values (n_rows=32567):
#                 n_missing  pct_missing
# mpg                  3840        11.79
# tax                  3469        10.65
# year                 1007         3.09
# transmission          968         2.97
# previousOwners        936         2.87
# engineSize            875         2.69
# mileage               859         2.64
# model                 751         2.31
# fuelType              656         2.01
# hasDamage             597         1.83
# Brand                  20         0.06
# #numeric_cols: 7 → ['year', 'mileage', 'tax', 'mpg', 'engineSize', 'previousOwners', 'hasDamage']
# #categorical_cols: 4 → ['Brand', 'model', 'transmission', 'fuelType']

# %% [markdown]
# <a id="sec-3-sanity"></a>
# ## 3. Imputation Strategies
#
# We will handle missing values using specific strategies for categorical and numerical features. Inbetween we split our data set into the different brands, more about that later.
# We define custom imputers that can be integrated into a pipeline.
#
# ### 3.1 Categorical Imputation
# Strategies for: `transmission`, `fuelType`, `Brand`, `model`.
# These imputers use a combination of rule-based logic (e.g., mode per model) and Random Forrest to fill missing values.

# %%
# Used for low-cardinality categorical features
low_cardinality_pipeline = Pipeline([
    ('onehot', OneHotEncoder(handle_unknown='ignore', sparse_output=False))
])

# Used for high-cardinality categorical features like model
high_cardinality_pipeline = Pipeline([
    ('ordinal', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1))
])

# Helper function to create specific pipelines for each imputer
# This ensures we only try to encode columns that are actually present as features
def create_imputation_pipeline(low_card_cols, high_card_cols=[]):
    transformers = []
    if low_card_cols:
        transformers.append(('low_card', low_cardinality_pipeline, low_card_cols))
    if high_card_cols:
        transformers.append(('high_card', high_cardinality_pipeline, high_card_cols))
        
    # remainder='passthrough' keeps the numerical columns
    encoder = ColumnTransformer(transformers, remainder='passthrough', verbose_feature_names_out=False)
    
    return Pipeline([
        ('encoder', encoder),
        ("rf_model", RandomForestClassifier(n_estimators=200, max_depth=10, random_state=42))
    ])
#mputes missing transmission values
class TransmissionImputer(BaseEstimator, TransformerMixin):
    
    def __init__(self, pipeline_template, min_model_count=10):
        #Preconfigured scikit-learn pipeline used to train the ML-based imputer.
        self.pipeline_template = pipeline_template
        # Minimum number of observations required for a car model to be considered reliable for rule-based imputation
        self.min_model_count = min_model_count

    def fit(self,
            X, #Input DataFrame containing features and the transmission column.
            y=None #Included for compatibility with scikit-learn transformers.
           ):
        df = X.copy()

        # store lookup tables learned from training data
        counts = df.dropna(subset=['transmission'])['model'].value_counts()
        # select models that appears more than 10 times
        self.valid_models_ = counts[counts >= self.min_model_count].index
        #group the models with the most_common_transmission 
        self.model_modes_ = (
            df.dropna(subset=['model', 'transmission'])
              .groupby('model')['transmission']
              .agg(lambda s: s.mode().iloc[0])
        )

        # Train ML model for remaining missin g values
        train_df = df[df['transmission'].notna()].copy()

        features = [
            "Brand", "model", "fuelType",
            "engineSize", "year", "mpg", "tax",
        ]

        pipe = clone(self.pipeline_template)
        pipe.fit(train_df[features], train_df['transmission'])

        self.ml_model_ = pipe
        self.features_ = features
        return self

    def transform(self, X):
        df = X.copy()

        # rule-based fill
        for model in self.valid_models_:
            mask = (df['model'] == model) & (df['transmission'].isna())
            #fill the transmission missing values with the most frequent transmission at the respective car model
            if model in self.model_modes_:
                df.loc[mask, 'transmission'] = self.model_modes_[model]

        # ML fallback
        missing_mask = df['transmission'].isna()
         #predict the missing transmission values with the Random Forest classifier
        if missing_mask.any():
            df.loc[missing_mask, 'transmission'] = self.ml_model_.predict(
                df.loc[missing_mask, self.features_]
            )
        return df

class FuelTypeImputer(BaseEstimator, TransformerMixin):
    
    def __init__(self, pipeline_template, min_model_count=10):
        # Preconfigured ML pipeline used for fuelType prediction
        self.pipeline_template = pipeline_template
        # Minimum number of observations required to trust rule-based imputation
        self.min_model_count = min_model_count

    def fit(self, X, y=None):
        df = X.copy()

        # Count how many times each model appears with a known fuelType
        counts = df.dropna(subset=['fuelType'])['model'].value_counts()

        # Select models with enough observations to trust rule-based imputation
        self.valid_models_ = counts[counts >= self.min_model_count].index

        # Compute the most frequent fuelType for each model
        self.model_modes_ = (
            df.dropna(subset=['model', 'fuelType'])
              .groupby('model')['fuelType']
              .agg(lambda s: s.mode().iloc[0])
        )

        # Features used by the ML fallback model
        features = [
            'Brand', 'model', 'transmission',
            'engineSize', 'year', 'mpg'
        ]

        # Training data where fuelType is known
        train_df = df[df['fuelType'].notna()]

        # Clone and train the ML model
        pipe = clone(self.pipeline_template)
        pipe.fit(train_df[features], train_df['fuelType'])

        # Store trained model and feature list
        self.ml_model_ = pipe
        self.features_ = features
        return self

    def transform(self, X):
        df = X.copy()

        #  Rule-based imputation
        # Fill missing fuelType values using model-level modes
        for model in self.valid_models_:
            mask = (df['model'] == model) & (df['fuelType'].isna())
            df.loc[mask, 'fuelType'] = self.model_modes_.get(model, np.nan)

        #  ML fallback
        # Predict remaining missing fuelType values using ML model (RandomForestClassifier)
        missing = df['fuelType'].isna()
        if missing.any():
            df.loc[missing, 'fuelType'] = self.ml_model_.predict(
                df.loc[missing, self.features_]
            )
        return df

class BrandImputer(BaseEstimator, TransformerMixin):
    
    def __init__(self, pipeline_template, min_model_count=20):
        # Preconfigured ML pipeline for brand prediction
        self.pipeline_template = pipeline_template
        # Minimum count threshold (kept higher due to brand importance)
        self.min_model_count = min_model_count

    def fit(self, X, y=None):
        df = X.copy()

        # Rule-based lookup: most common brand per model
        self.model_to_brand_ = (
            df.dropna(subset=['Brand', 'model'])
              .groupby('model')['Brand']
              .agg(lambda s: s.mode().iloc[0])
        )

        # ML fallback features
        features = [
            'transmission', 'engineSize',
            'fuelType', 'mpg', 'model'
        ]

        # Training data where Brand is known
        train_df = df[df['Brand'].notna()]

        # Train ML model
        pipe = clone(self.pipeline_template)
        pipe.fit(train_df[features], train_df['Brand'])

        # Store trained model and features
        self.ml_model_ = pipe
        self.features_ = features
        return self

    def transform(self, X):
        df = X.copy()

        #  Rule-based imputation
        # Fill missing Brand values using model to brand lookup
        mask = df['Brand'].isna() & df['model'].notna()
        df.loc[mask, 'Brand'] = df.loc[mask, 'model'].map(self.model_to_brand_)

        # ML fallback
        # Predict remaining missing Brand values
        missing = df['Brand'].isna()
        if missing.any():
            df.loc[missing, 'Brand'] = self.ml_model_.predict(
                df.loc[missing, self.features_]
            )
        return df

class ModelImputer(BaseEstimator, TransformerMixin):
    
    def __init__(self, pipeline_template, min_brand_count=20):
        # Preconfigured ML pipeline for model prediction
        self.pipeline_template = pipeline_template
        # Minimum count threshold for rule-based logic
        self.min_brand_count = min_brand_count

    def fit(self, X, y=None):
        df = X.copy()

        # Rule-based lookup:
        # Most frequent model for each (Brand, transmission) pair
        self.lookup_ = (
            df.dropna(subset=['Brand', 'transmission', 'model'])
              .groupby(['Brand', 'transmission'])['model']
              .agg(lambda s: s.value_counts().idxmax())
        )

        # ML fallback features
        features = [
            'Brand', 'year', 'engineSize', 'mpg',
            'tax', 'mileage', 'fuelType', 'transmission'
        ]

        # Training data where model is known
        train_df = df[df['model'].notna()]

        # Train ML model
        pipe = clone(self.pipeline_template)
        pipe.fit(train_df[features], train_df['model'])

        # Store trained model and features
        self.ml_model_ = pipe
        self.features_ = features
        return self

    def transform(self, X):
        df = X.copy()

        # Rule-based imputation 
        # Fill missing model values using (Brand, transmission) lookup
        for idx, row in df[df['model'].isna()].iterrows():
            key = (row['Brand'], row['transmission'])
            if key in self.lookup_.index:
                df.at[idx, 'model'] = self.lookup_.loc[key]

        # ML fallback
        # Predict remaining missing model values
        missing = df['model'].isna()
        if missing.any():
            df.loc[missing, 'model'] = self.ml_model_.predict(
                df.loc[missing, self.features_]
            )
        return df

# %% [markdown]
# In the next cell we impute the categorical values for train, val and test data. We only use train data to fit the imputer.

# %%
# Feature subsets used by each imputer
# Each imputer only receives columns that are relevant for its task
trans_features = ["Brand", "model", "fuelType", "engineSize", "year", "mpg", "tax"]
fuel_features  = ["Brand", "model", "transmission", "engineSize", "year", "mpg"]
brand_features = ["transmission", "engineSize", "fuelType", "mpg", "model"]
model_features = ["Brand", "year", "engineSize", "mpg", "tax", "mileage", "fuelType", "transmission"]

# Create imputers with restricted feature templates
trans_imputer = TransmissionImputer(make_template_for(trans_features))
fuel_imputer  = FuelTypeImputer(make_template_for(fuel_features))
brand_imputer = BrandImputer(make_template_for(brand_features))
model_imputer = ModelImputer(make_template_for(model_features))

# Fit imputers ONLY on training data (to avoid leakage)
for imp in [trans_imputer, fuel_imputer, brand_imputer, model_imputer]:
    imp.fit(x_train)

# Apply the trained imputers to all data splits
x_train_imp = apply_imputers(x_train)
x_val_imp   = apply_imputers(x_val)
x_test_imp  = apply_imputers(x_test)

# %% [markdown]
# The next cell just checks if we successfully removed the categorical missing values, which we did.

# %%
missing_report(x_train_imp, "x_train_imp")
missing_report(x_val_imp,   "x_val_imp")
missing_report(x_test_imp,  "x_test_imp")
# Out:
# [x_train_imp] Missing Values (n_rows=63296):
#                 n_missing  pct_missing
# mpg                  7653        12.09
# tax                  6892        10.89
# engineSize           1742         2.75
# previousOwners       1596         2.52
# mileage              1525         2.41
# hasDamage            1274         2.01
# year                  310         0.49
# [x_val_imp] Missing Values (n_rows=11171):
#                 n_missing  pct_missing
# mpg                  1351        12.09
# tax                  1216        10.89
# engineSize            313         2.80
# previousOwners        292         2.61
# mileage               276         2.47
# hasDamage             247         2.21
# year                   48         0.43
# [x_test_imp] Missing Values (n_rows=32567):
#                 n_missing  pct_missing
# mpg                  3840        11.79
# tax                  3469        10.65
# year                 1007         3.09
# previousOwners        936         2.87
# engineSize            875         2.69
# mileage               859         2.64
# hasDamage             597         1.83
#                 n_missing  pct_missing
# mpg                  3840        11.79
# tax                  3469        10.65
# year                 1007         3.09
# previousOwners        936         2.87
# engineSize            875         2.69
# mileage               859         2.64
# hasDamage             597         1.83

# %% [markdown]
# ## Intermediate step: Split Brands

# %% [markdown]
# After having no missing values in brands left, we can split the data sets into the different brands. In the next cell we check the distribution of brands in our train data.

# %%
x_train_imp['Brand'].value_counts()
# Out:
# Brand
# Ford             13658
# Mercedes-Benz     9913
# Volkswagen        8835
# Opel              7957
# BMW               6283
# Audi              6226
# Toyota            3938
# Škoda             3649
# Hyundai           2837
# Name: count, dtype: int64

# %% [markdown]
# We now split the train data into the brands seen in the cell before, we also need to split the y_train values.

# %%
# assumes: x_train and y_train have matching indices
brand_splits = {}

for brand, X_b in x_train_imp.groupby("Brand"):
    y_b = y_train.loc[X_b.index]   # pick same rows in y
    brand_splits[brand] = (X_b, y_b)

x_train_ford, y_train_ford = brand_splits["Ford"]
x_train_merc, y_train_merc = brand_splits["Mercedes-Benz"]
x_train_volk, y_train_volk = brand_splits["Volkswagen"]
x_train_opel, y_train_opel = brand_splits["Opel"]
x_train_bmw, y_train_bmw = brand_splits["BMW"]
x_train_audi, y_train_audi = brand_splits["Audi"]
x_train_toyo, y_train_toyo = brand_splits["Toyota"]
x_train_skod, y_train_skod = brand_splits["Škoda"]
x_train_hyun, y_train_hyun = brand_splits["Hyundai"]

# %% [markdown]
# We do the same for validation data.

# %%
# assumes: x_train and y_train have matching indices
brand_splits = {}

for brand, X_b in x_val_imp.groupby("Brand"):
    y_b = y_val.loc[X_b.index]   # pick same rows in y
    brand_splits[brand] = (X_b, y_b)

x_val_ford, y_val_ford = brand_splits["Ford"]
x_val_merc, y_val_merc = brand_splits["Mercedes-Benz"]
x_val_volk, y_val_volk = brand_splits["Volkswagen"]
x_val_opel, y_val_opel = brand_splits["Opel"]
x_val_bmw, y_val_bmw = brand_splits["BMW"]
x_val_audi, y_val_audi = brand_splits["Audi"]
x_val_toyo, y_val_toyo = brand_splits["Toyota"]
x_val_skod, y_val_skod = brand_splits["Škoda"]
x_val_hyun, y_val_hyun = brand_splits["Hyundai"]

# %% [markdown]
# And also for test data.

# %%
brand_splits = {}

for brand, X_b in x_test_imp.groupby("Brand"):
    brand_splits[brand] = X_b

x_test_ford = brand_splits["Ford"]
x_test_merc = brand_splits["Mercedes-Benz"]
x_test_volk = brand_splits["Volkswagen"]
x_test_opel = brand_splits["Opel"]
x_test_bmw = brand_splits["BMW"]
x_test_audi = brand_splits["Audi"]
x_test_toyo = brand_splits["Toyota"]
x_test_skod = brand_splits["Škoda"]
x_test_hyun = brand_splits["Hyundai"]

# %% [markdown]
# With those dataframes we build list, so that we can iterate over them.

# %%
train_x_list = [x_train_ford, x_train_merc, x_train_volk, x_train_opel, x_train_bmw, 
x_train_audi, x_train_toyo, x_train_skod, x_train_hyun]

train_y_list = [y_train_ford, y_train_merc, y_train_volk, y_train_opel, y_train_bmw, 
y_train_audi, y_train_toyo, y_train_skod, y_train_hyun]

val_x_list = [x_val_ford, x_val_merc, x_val_volk, x_val_opel, x_val_bmw, 
x_val_audi, x_val_toyo, x_val_skod, x_val_hyun]

val_y_list = [y_val_ford, y_val_merc, y_val_volk, y_val_opel, y_val_bmw, 
y_val_audi, y_val_toyo, y_val_skod, y_val_hyun]

test_x_list = [x_test_ford, x_test_merc, x_test_volk, x_test_opel, x_test_bmw, 
x_test_audi, x_test_toyo, x_test_skod, x_test_hyun]

# %% [markdown]
# We then drop the brand column, because its useless after the split.

# %%
train_x_list = [df.drop(columns=['Brand']) for df in train_x_list]

val_x_list = [df.drop(columns=['Brand']) for df in val_x_list]

test_x_list = [df.drop(columns=['Brand']) for df in test_x_list]

# %% [markdown]
# ## 3.2 Numerical Imputation
# Strategies for: `mileage`, `year`, `mpg`, `tax`, `engineSize`, `previousOwners`.
# These imputers primarily use median values, grouped by relevant features (e.g., median mileage per year) to ensure realistic fills.

# %%
class MileageImputer(BaseEstimator, TransformerMixin):
    """
    Imputer for missing 'mileage values:
    Fill missing values with median mileage for the car's year.
    Fill remaining missing values with mileage median.
    """
    def fit(self, X, y=None):
        df = X.copy()
        # Median mileage per year, captures typical mileage for a given car age
        self.year_medians_ = df.groupby('year')['mileage'].median()
        # Global median mileage → fallback for missing years
        self.global_median_ = df['mileage'].median()
        return self

    def transform(self, X):
        df = X.copy()
        # Fill using median mileage per year
        df['mileage'] = df['mileage'].fillna(df['year'].map(self.year_medians_))
        # Fill remaining missing values with mileage median
        df['mileage'] = df['mileage'].fillna(self.global_median_)
        return df


class YearImputer(BaseEstimator, TransformerMixin):
    """
    Imputer for missing year values using mileage-based binning:
    Bin mileage into fixed number of bins and fill missing years using bin median.
    Fill remaining missing years with year median.
    """
    def __init__(self, bins=30):
        # Number of bins to divide mileage into
        self.bins = bins

    def fit(self, X, y=None):
        df = X.copy()
        # Create mileage bins
        df['mileage_bin'] = pd.cut(df['mileage'], bins=self.bins)
        # Median year per mileage bin, approximates car age from mileage
        self.bin_medians_ = df.groupby('mileage_bin')['year'].median()
        # median year, used on fallback
        self.global_median_ = df['year'].median()
        return self

    def transform(self, X):
        df = X.copy()
        # Bin mileage same as in fit
        df['mileage_bin'] = pd.cut(df['mileage'], bins=self.bins)
        # Fill missing years using bin medians
        df['year'] = df['year'].fillna(df['mileage_bin'].map(self.bin_medians_))
        # Fill remaining missing years using year median
        df['year'] = df['year'].fillna(self.global_median_)
        # Remove temporary bin column
        df.drop(columns='mileage_bin', inplace=True)
        return df


class MPGImputer(BaseEstimator, TransformerMixin):
    """
    Imputer for missing mpg values:
    Median mpg per (model, fuelType)
    Median mpg per fuelType
    Median mpg
    """
    def fit(self, X, y=None):
        df = X.copy()
        # Median mpg per (model, fuelType)
        self.model_medians_ = df.groupby(['model', 'fuelType'])['mpg'].median()
        # Median mpg per fuelType
        self.fuel_medians_ = df.groupby('fuelType')['mpg'].median()
        # year median for fallback
        self.global_median_ = df['mpg'].median()
        return self

    def transform(self, X):
        df = X.copy()
        # Fill using (model, fuelType) median
        for idx, row in df[df['mpg'].isna()].iterrows():
            km = (row['model'], row['fuelType'])
            if km in self.model_medians_.index:
                df.at[idx, 'mpg'] = self.model_medians_.loc[km]
        # Fill remaining using fuelType median
        df['mpg'] = df['mpg'].fillna(df['fuelType'].map(self.fuel_medians_))
        # Fill remaining using mpg median
        df['mpg'] = df['mpg'].fillna(self.global_median_)
        return df


class PreviousOwnersImputer(BaseEstimator, TransformerMixin):
    """
    Imputer for previousOwners using previousOwners median.
    Simple imputation since previousOwners is low-cardinality.
    """
    def fit(self, X, y=None):
        # Store global median, used to fill all missing values
        self.median_ = X['previousOwners'].median()
        return self

    def transform(self, X):
        df = X.copy()
        df['previousOwners'] = df['previousOwners'].fillna(self.median_)
        return df


class TaxImputer(BaseEstimator, TransformerMixin):
    """
    Imputer for missing tax values:
    Median tax per (model, fuelType, mpg_bin)
    Median tax per (fuelType, mpg_bin)
    Median tax per fuelType
    Median tax
    """
    def __init__(self, bins=15):
        # Number of bins to discretize mpg
        self.bins = bins

    def fit(self, X, y=None):
        df = X.copy()
        df['mpg_bin'] = pd.cut(df['mpg'], bins=self.bins)
        # Compute all medians
        self.medians_one_ = df.groupby(['model', 'fuelType', 'mpg_bin'])['tax'].median()
        self.medians_two_ = df.groupby(['fuelType', 'mpg_bin'])['tax'].median()
        self.fuel_medians_ = df.groupby('fuelType')['tax'].median()
        self.global_median_ = df['tax'].median()
        return self

    def transform(self, X):
        df = X.copy()
        df['mpg_bin'] = pd.cut(df['mpg'], bins=self.bins)
        # Hierarchical filling
        for idx, row in df[df['tax'].isna()].iterrows():
            km = (row['model'], row['fuelType'], row['mpg_bin'])
            ke = (row['fuelType'], row['mpg_bin'])
            if km in self.medians_one_.index:
                df.at[idx, 'tax'] = self.medians_one_.loc[km]
            elif ke in self.medians_two_.index:
                df.at[idx, 'tax'] = self.medians_two_.loc[ke]
        # Fallbacks
        df['tax'] = df['tax'].fillna(df['fuelType'].map(self.fuel_medians_))
        df['tax'] = df['tax'].fillna(self.global_median_)
        # Remove temporary bin column
        df.drop(columns='mpg_bin', inplace=True)
        return df


class EngineSizeImputer(BaseEstimator, TransformerMixin):
    """
    Imputer for missing engineSize values:
    Median per (model, fuelType)
    Median per model
    EngineSize median
    """
    def fit(self, X, y=None):
        df = X.copy()
        # Median engineSize per (model, fuelType)
        self.model_medians_ = df.groupby(['model', 'fuelType'])['engineSize'].median()
        # Median engineSize per model
        self.model_only_medians_ = df.groupby('model')['engineSize'].median()
        # EngineSize median
        self.global_median_ = df['engineSize'].median()
        return self

    def transform(self, X):
        df = X.copy()
        # Fill using (model, fuelType) median
        for idx, row in df[df['engineSize'].isna()].iterrows():
            km = (row['model'], row['fuelType'])
            if km in self.model_medians_.index:
                df.at[idx, 'engineSize'] = self.model_medians_.loc[km]
        # Fill using model-only median
        df['engineSize'] = df['engineSize'].fillna(df['model'].map(self.model_only_medians_))
        # Fill remaining using EngineSize median
        df['engineSize'] = df['engineSize'].fillna(self.global_median_)
        return df

# %% [markdown]
# Now we create the pipeline to impute the last missing values.

# %%
rule_imputer = Pipeline([
    ("mileage_imp", MileageImputer()),
    ("year_imp", YearImputer()),
    ("mpg_imp", MPGImputer()),
    ("previousOwners_imp", PreviousOwnersImputer()),
    ("tax_imp", TaxImputer()),
    ("engineSize_imp", EngineSizeImputer()),
])

# %% [markdown]
# We then train this imputers on train data of the specific brand and then impute the train, val and test data.

# %%
for i in range(len(train_x_list)):

    # Fit imputers only on the training data
    # This prevents data leakage from validation or test sets
    # Ensures that any statistics (medians, bins, etc.) are computed purely from the training data
    rule_imputer.fit(train_x_list[i])

    # Apply the trained imputers to all splits 
    # Sequentially fill missing values in train, validation, and test sets
    # Uses only information learned from the training set
    train_x_list[i] = rule_imputer.transform(train_x_list[i])
    val_x_list[i]   = rule_imputer.transform(val_x_list[i])
    test_x_list[i]  = rule_imputer.transform(test_x_list[i])
# Out:
# C:\Users\gmbtd\AppData\Local\Temp\ipykernel_7944\2723973335.py:22: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   self.bin_medians_ = df.groupby('mileage_bin')['year'].median()
# C:\Users\gmbtd\AppData\Local\Temp\ipykernel_7944\2723973335.py:77: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   self.medians_one_ = df.groupby(['model', 'fuelType', 'mpg_bin'])['tax'].median()
# C:\Users\gmbtd\AppData\Local\Temp\ipykernel_7944\2723973335.py:78: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   self.medians_two_ = df.groupby(['fuelType', 'mpg_bin'])['tax'].median()
# C:\Users\gmbtd\AppData\Local\Temp\ipykernel_7944\2723973335.py:22: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   self.bin_medians_ = df.groupby('mileage_bin')['year'].median()
# C:\Users\gmbtd\AppData\Local\Temp\ipykernel_7944\2723973335.py:77: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   self.medians_one_ = df.groupby(['model', 'fuelType', 'mpg_bin'])['tax'].median()
# C:\Users\gmbtd\AppData\Local\Temp\ipykernel_7944\2723973335.py:78: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   self.medians_two_ = df.groupby(['fuelType', 'mpg_bin'])['tax'].median()
# C:\Users\gmbtd\AppData\Local\Temp\ipykernel_7944\2723973335.py:22: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   self.bin_medians_ = df.groupby('mileage_bin')['year'].median()
# C:\Users\gmbtd\AppData\Local\Temp\ipykernel_7944\2723973335.py:77: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   self.medians_one_ = df.groupby(['model', 'fuelType', 'mpg_bin'])['tax'].median()
# C:\Users\gmbtd\AppData\Local\Temp\ipykernel_7944\2723973335.py:78: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   self.medians_two_ = df.groupby(['fuelType', 'mpg_bin'])['tax'].median()
# C:\Users\gmbtd\AppData\Local\Temp\ipykernel_7944\2723973335.py:22: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   self.bin_medians_ = df.groupby('mileage_bin')['year'].median()
# C:\Users\gmbtd\AppData\Local\Temp\ipykernel_7944\2723973335.py:77: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   self.medians_one_ = df.groupby(['model', 'fuelType', 'mpg_bin'])['tax'].median()
# C:\Users\gmbtd\AppData\Local\Temp\ipykernel_7944\2723973335.py:78: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   self.medians_two_ = df.groupby(['fuelType', 'mpg_bin'])['tax'].median()
# C:\Users\gmbtd\AppData\Local\Temp\ipykernel_7944\2723973335.py:22: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   self.bin_medians_ = df.groupby('mileage_bin')['year'].median()
# C:\Users\gmbtd\AppData\Local\Temp\ipykernel_7944\2723973335.py:77: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   self.medians_one_ = df.groupby(['model', 'fuelType', 'mpg_bin'])['tax'].median()
# C:\Users\gmbtd\AppData\Local\Temp\ipykernel_7944\2723973335.py:78: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   self.medians_two_ = df.groupby(['fuelType', 'mpg_bin'])['tax'].median()
# C:\Users\gmbtd\AppData\Local\Temp\ipykernel_7944\2723973335.py:22: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   self.bin_medians_ = df.groupby('mileage_bin')['year'].median()
# C:\Users\gmbtd\AppData\Local\Temp\ipykernel_7944\2723973335.py:77: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   self.medians_one_ = df.groupby(['model', 'fuelType', 'mpg_bin'])['tax'].median()
# C:\Users\gmbtd\AppData\Local\Temp\ipykernel_7944\2723973335.py:78: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   self.medians_two_ = df.groupby(['fuelType', 'mpg_bin'])['tax'].median()
# C:\Users\gmbtd\AppData\Local\Temp\ipykernel_7944\2723973335.py:22: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   self.bin_medians_ = df.groupby('mileage_bin')['year'].median()
# C:\Users\gmbtd\AppData\Local\Temp\ipykernel_7944\2723973335.py:77: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   self.medians_one_ = df.groupby(['model', 'fuelType', 'mpg_bin'])['tax'].median()
# C:\Users\gmbtd\AppData\Local\Temp\ipykernel_7944\2723973335.py:78: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   self.medians_two_ = df.groupby(['fuelType', 'mpg_bin'])['tax'].median()
# C:\Users\gmbtd\AppData\Local\Temp\ipykernel_7944\2723973335.py:22: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   self.bin_medians_ = df.groupby('mileage_bin')['year'].median()
# C:\Users\gmbtd\AppData\Local\Temp\ipykernel_7944\2723973335.py:77: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   self.medians_one_ = df.groupby(['model', 'fuelType', 'mpg_bin'])['tax'].median()
# C:\Users\gmbtd\AppData\Local\Temp\ipykernel_7944\2723973335.py:78: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   self.medians_two_ = df.groupby(['fuelType', 'mpg_bin'])['tax'].median()
# C:\Users\gmbtd\AppData\Local\Temp\ipykernel_7944\2723973335.py:22: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   self.bin_medians_ = df.groupby('mileage_bin')['year'].median()
# C:\Users\gmbtd\AppData\Local\Temp\ipykernel_7944\2723973335.py:77: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   self.medians_one_ = df.groupby(['model', 'fuelType', 'mpg_bin'])['tax'].median()
# C:\Users\gmbtd\AppData\Local\Temp\ipykernel_7944\2723973335.py:78: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   self.medians_two_ = df.groupby(['fuelType', 'mpg_bin'])['tax'].median()

# %% [markdown]
# Because hasDamage only has the value 0 and nan, we set nan to 1 to see if atleast this holds a different value, otherwise it will be useless.

# %%
for i in range(len(train_x_list)):
    train_x_list[i]["hasDamage"] = train_x_list[i]["hasDamage"].fillna(1)
    val_x_list[i]["hasDamage"] = val_x_list[i]["hasDamage"].fillna(1)
    test_x_list[i]["hasDamage"] = test_x_list[i]["hasDamage"].fillna(1)

# %% [markdown]
# After that we check, if all missing values are gone.

# %%
for i in range(len(train_x_list)):
    missing_report(train_x_list[i], f"train_x: {i}")
    missing_report(val_x_list[i],   f"val_x: {i}")
    missing_report(test_x_list[i],  f"test_x: {i}")
# Out:
# [train_x: 0] No missing values found. (n_rows=13658)
# [val_x: 0] No missing values found. (n_rows=2410)
# [test_x: 0] No missing values found. (n_rows=7027)
# [train_x: 1] No missing values found. (n_rows=9913)
# [val_x: 1] No missing values found. (n_rows=1749)
# [test_x: 1] No missing values found. (n_rows=5108)
# [train_x: 2] No missing values found. (n_rows=8835)
# [val_x: 2] No missing values found. (n_rows=1561)
# [test_x: 2] No missing values found. (n_rows=4551)
# [train_x: 3] No missing values found. (n_rows=7957)
# [val_x: 3] No missing values found. (n_rows=1404)
# [test_x: 3] No missing values found. (n_rows=4090)
# [train_x: 4] No missing values found. (n_rows=6283)
# [val_x: 4] No missing values found. (n_rows=1109)
# [test_x: 4] No missing values found. (n_rows=3228)
# [train_x: 5] No missing values found. (n_rows=6226)
# [val_x: 5] No missing values found. (n_rows=1099)
# [test_x: 5] No missing values found. (n_rows=3203)
# [train_x: 6] No missing values found. (n_rows=3938)
# [val_x: 6] No missing values found. (n_rows=695)
# [test_x: 6] No missing values found. (n_rows=2022)
# [train_x: 7] No missing values found. (n_rows=3649)
# [val_x: 7] No missing values found. (n_rows=643)
# [test_x: 7] No missing values found. (n_rows=1881)
# [train_x: 8] No missing values found. (n_rows=2837)
# [val_x: 8] No missing values found. (n_rows=501)
# [test_x: 8] No missing values found. (n_rows=1457)

# %% [markdown]
# ## 5. Feature Engineering

# %% [markdown]
# For feature enginnering, we try to not create to much new noise for our models, we just add a few features. He we declare the class to use them.

# %%
class FeatureEngineeringTransformer(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        df = X.copy()

        # Compute the median MPG for each transmission type
        self.trans_medians_ = df.groupby('transmission')['mpg'].median()

        # Compute 75th and 90th percentiles of mileage
        # These will be used to flag high- and very-high mileage cars, which often have lower resale value
        self.mileage_q75_ = df['mileage'].quantile(0.75)
        self.mileage_q90_ = df['mileage'].quantile(0.90)

        return self

    def transform(self, X):
        df = X.copy()

        # Difference of car's MPG from median MPG for its transmission type
        # Helps capture whether the car is more or less fuel-efficient than typical for its transmission
        mpg_median_trans = df['transmission'].map(self.trans_medians_)
        mpg_median_trans = mpg_median_trans.fillna(self.trans_medians_.median())  # fallback in case transmission missing
        df['mpg_diff_transmission'] = (df['mpg'] - mpg_median_trans).fillna(0)

        # Car age in years
        df['car_age'] = 2020 - df['year']

        # mpg per unit of engine size
        # Provides a normalized measure of fuel efficiency
        df['efficiency_ratio'] = df['mpg'] / (df['engineSize'] + 0.1)

        # Average annual mileage
        # Helps differentiate cars with heavy usage vs light usage
        df['mileage_per_year'] = df['mileage'] / (df['car_age'] + 0.1)

        # High-mileage flags
        # Binary flags indicating unusually high or very high mileage cars
        df['high_mileage_flag'] = (df['mileage'] > self.mileage_q75_).astype(int)
        df['very_high_mileage_flag'] = (df['mileage'] > self.mileage_q90_).astype(int)

        return df

# %% [markdown]
# Here we apply those features to our dataframes.

# %%
for i in range(len(train_x_list)):

    # Initialize a new feature engineering transformer for this brand
    fe = FeatureEngineeringTransformer()

    # fit only on the training data
    # Ensures that any statistics (medians, percentiles) are computed without data leakage from validation/test
    fe.fit(train_x_list[i])

    # transform on all splits: train, validation, and test
    # Sequentially adds engineered features like mpg_diff_transmission, car_age, efficiency_ratio, mileage_per_year,
    # and high-mileage flags
    train_x_list[i] = fe.transform(train_x_list[i])
    val_x_list[i]   = fe.transform(val_x_list[i])
    test_x_list[i]  = fe.transform(test_x_list[i])

# %% [markdown]
# ## 6. Scaling

# %% [markdown]
# For the models in this notebook, we decided to not use scaling, since it didnt change the score significantly (score was around 1 MAE worse).

# %%
"""
for i in range(len(train_x_list)):
    num_cols = train_x_list[i].select_dtypes(include="number").columns
    non_num_cols = train_x_list[i].columns.difference(num_cols)

    scaler = RobustScaler()
    scaler.fit(train_x_list[i][num_cols])

    train_scaled = scaler.transform(train_x_list[i][num_cols])
    val_scaled   = scaler.transform(val_x_list[i][num_cols])
    test_scaled  = scaler.transform(test_x_list[i][num_cols])

    train_x_list[i] = pd.concat([
        pd.DataFrame(train_scaled, columns=num_cols, index=train_x_list[i].index),
        train_x_list[i][non_num_cols]
    ], axis=1)[train_x_list[i].columns]

    val_x_list[i] = pd.concat([
        pd.DataFrame(val_scaled, columns=num_cols, index=val_x_list[i].index),
        val_x_list[i][non_num_cols]
    ], axis=1)[val_x_list[i].columns]

    test_x_list[i] = pd.concat([
        pd.DataFrame(test_scaled, columns=num_cols, index=test_x_list[i].index),
        test_x_list[i][non_num_cols]
    ], axis=1)[test_x_list[i].columns]
"""
# Out:
# '\nfor i in range(len(train_x_list)):\n    num_cols = train_x_list[i].select_dtypes(include="number").columns\n    non_num_cols = train_x_list[i].columns.difference(num_cols)\n\n    scaler = RobustScaler()\n    scaler.fit(train_x_list[i][num_cols])\n\n    train_scaled = scaler.transform(train_x_list[i][num_cols])\n    val_scaled   = scaler.transform(val_x_list[i][num_cols])\n    test_scaled  = scaler.transform(test_x_list[i][num_cols])\n\n    train_x_list[i] = pd.concat([\n        pd.DataFrame(train_scaled, columns=num_cols, index=train_x_list[i].index),\n        train_x_list[i][non_num_cols]\n    ], axis=1)[train_x_list[i].columns]\n\n    val_x_list[i] = pd.concat([\n        pd.DataFrame(val_scaled, columns=num_cols, index=val_x_list[i].index),\n        val_x_list[i][non_num_cols]\n    ], axis=1)[val_x_list[i].columns]\n\n    test_x_list[i] = pd.concat([\n        pd.DataFrame(test_scaled, columns=num_cols, index=test_x_list[i].index),\n        test_x_list[i][non_num_cols]\n    ], axis=1)[test_x_list[i].columns]\n'

# %% [markdown]
# ## 7. Encoding

# %% [markdown]
# For encoding we decided to try to use both Target Encoding and One Hot Encoding next to each other. We also decided to look at the different models for each brand and how many entities we have per model.

# %%
for df in train_x_list:
    print("\n")
    print(df["model"].value_counts())
# Out:
# model
# Focus                    6007
# Fiesta                   3744
# Kuga                     1262
# EcoSport                  686
# C-MAX                     322
# Ka+                       312
# Mondeo                    297
# B-MAX                     207
# S-MAX                     160
# Ka                        131
# Grand C-MAX               121
# Galaxy                    116
# Edge                      113
# Puma                       44
# Tourneo Custom             39
# Grand Tourneo Connect      35
# Mustang                    32
# Tourneo Connect            17
# Fusion                     12
# StreetKa                    1
# Name: count, dtype: int64
#
#
# model
# C-Class      4580
# A-Class      1482
# E-Class      1082
# GLC-Class     555
# GLA-Class     471
# B-Class       340
# CL-Class      271
# GLE-Class     263
# SL-Class      161
# CLS-Class     138
# V-Class       121
# S-Class       112
# GL-Class       71
# SLK-Class      56
# X-Class        51
# CLA-Class      50
# GLS-Class      44
# M-Class        40
# GLB-Class      11
# G-Class         9
# CLK-Class       5
# Name: count, dtype: int64
#
#
# model
# Golf               2977
# Polo               1852
# Tiguan             1015
# Passat              533
# Up                  478
# T-Roc               418
# Touareg             207
# Touran              200
# T-Cross             185
# Sharan              156
# Golf SV             148
# Arteon              142
# Scirocco            139
# Amarok               72
# Caravelle            57
# CC                   49
# Beetle               48
# Tiguan Allspace      44
# Caddy Maxi Life      35
# Shuttle              34
# Jetta                21
# California            7
# Eos                   5
# Caddy Life            5
# Caddy Maxi            4
# Caddy                 4
# Name: count, dtype: int64
#
#
# model
# Corsa            2141
# Astra            1595
# Mokka X          1188
# Insignia          603
# Mokka             488
# Crossland X       414
# Grandland X       317
# Zafira            312
# Adam              274
# Viva              263
# Meriva            153
# Combo Life         80
# GTC                53
# Zafira Tourer      22
# Vivaro             19
# Agila              14
# Antara             13
# Cascada             3
# Tigra               2
# Vectra              2
# Ampera              1
# Name: count, dtype: int64
#
#
# model
# 3 Series    1500
# 1 Series    1165
# 2 Series     710
# 5 Series     624
# 4 Series     555
# X1           448
# X3           300
# X5           263
# X2           158
# X4           105
# M4            72
# Z4            66
# 7 Series      64
# X6            64
# 6 Series      56
# X7            31
# 8 Series      27
# i3            22
# M3            17
# M5            15
# i8            12
# M2             6
# M6             2
# Z3             1
# Name: count, dtype: int64
#
#
# model
# A3     1272
# A4      835
# Q3      797
# A1      750
# Q5      499
# A5      490
# Q2      459
# A6      402
# Q7      236
# TT      184
# A8       69
# A7       65
# Q8       33
# RS6      30
# RS3      22
# R8       17
# RS4      15
# RS5      13
# S3       13
# S4        9
# SQ5       7
# SQ7       4
# S8        3
# A2        1
# S5        1
# Name: count, dtype: int64
#
#
# model
# Yaris            1235
# Aygo             1192
# Auris             420
# CH-R              279
# RAV4              271
# Corolla           133
# Prius             129
# Avensis            67
# Verso              65
# Hilux              42
# GT86               41
# Land Cruiser       27
# Proace Verso        9
# Supra               9
# Camry               8
# C-HR                3
# iQ                  3
# Verso-S             3
# Urban Cruiser       2
# Name: count, dtype: int64
#
#
# model
# Fabia           917
# Octavia         881
# Superb          436
# Kodiaq          276
# Yeti Outdoor    275
# Citigo          272
# Karoq           211
# Scala           117
# Rapid            89
# Kamiq            84
# Yeti             78
# Roomster         13
# Name: count, dtype: int64
#
#
# model
# Tucson      777
# i10         654
# i30         296
# i20         280
# Kona        190
# Ioniq       184
# Santa Fe    124
# ix20        123
# ix35         68
# i40          64
# i800         61
# i3            8
# Getz          6
# Terracan      1
# Veloster      1
# Name: count, dtype: int64

# %% [markdown]
# We saw that we have a few models, that dont have that many appearances. To prevent noise and overfitting, we decided to cluster all models under 20 appearances to other.
# A threshold of 20 provided a good balance:
#  - It removed extremely rare categories that would otherwise behave like noise,
#  - While still preserving the majority of meaningful model groups.

# %%
min_count = 20  # Minimum occurrences for a model to be kept; rare models will be grouped as "Other"

for i in range(len(train_x_list)):

    # Compute frequency of each model in the training set
    freq = train_x_list[i]["model"].value_counts()

    # Identify models that appear fewer times than min_count
    rare_models = freq[freq < min_count].index

    # Replace rare models with "Other" in the training set
    train_x_list[i]["model"] = train_x_list[i]["model"].replace(rare_models, "Other")

    # Apply the same replacement to validation set to avoid unseen rare categories
    val_x_list[i]["model"] = val_x_list[i]["model"].replace(rare_models, "Other")

    # Apply the same replacement to test set to maintain consistency
    test_x_list[i]["model"] = test_x_list[i]["model"].replace(rare_models, "Other")

# %% [markdown]
# After that we perform the encoding.

# %%
# Columns to be one-hot encoded
onehot_cols = ['Brand', 'fuelType', 'transmission', 'model', 'brand_segment', 'car_segment']

# Columns for target encoding
target_cols = onehot_cols

# Lists to store encoded DataFrames
train_x_encoded_list = []
val_x_encoded_list   = []
test_x_encoded_list  = []

for i in range(len(train_x_list)):

    # Current split
    X_train_i = train_x_list[i]
    X_val_i   = val_x_list[i]
    X_test_i  = test_x_list[i]
    y_train_i = train_y_list[i]  # Needed for target encoding

    # Only keep columns that actually exist in this dataset
    onehot_cols_i  = [c for c in onehot_cols if c in X_train_i.columns]
    target_cols_i  = [c for c in target_cols if c in X_train_i.columns]

    # One-Hot Encoder (ignore unknown categories in val/test)
    onehot_encoder = OneHotEncoder(
        handle_unknown='ignore',
        sparse_output=False
    )

    # Target Encoder for continuous target
    # Learns mean of target for each category
    target_encoder = TargetEncoder(
        target_type="continuous",              
        random_state=42
    )

    # ColumnTransformer applies one-hot and target encoding in parallel
    encoding_transformer = ColumnTransformer(
        transformers=[
            ('onehot', onehot_encoder, onehot_cols_i),
            ('target', target_encoder, target_cols_i),
        ],
        remainder='passthrough',  # keep other numeric columns as-is
        verbose_feature_names_out=False
    )

    print(f"\n[{i}] fitting encoder on train_x_list[{i}] "
          f"with onehot: {onehot_cols_i} and target-enc: {target_cols_i}")

    # Fit transformer on training data (important to give y for TargetEncoder)
    encoding_transformer.fit(X_train_i, y_train_i)

    # Transform all splits
    train_arr = encoding_transformer.transform(X_train_i)
    val_arr   = encoding_transformer.transform(X_val_i)
    test_arr  = encoding_transformer.transform(X_test_i)

    # Get the feature names after encoding
    feature_names = encoding_transformer.get_feature_names_out()

    # Convert arrays back to DataFrames with proper indices
    X_train_enc = pd.DataFrame(train_arr, columns=feature_names, index=X_train_i.index)
    X_val_enc   = pd.DataFrame(val_arr,   columns=feature_names, index=X_val_i.index)
    X_test_enc  = pd.DataFrame(test_arr,  columns=feature_names, index=X_test_i.index)

    # Append encoded splits to their respective lists
    train_x_encoded_list.append(X_train_enc)
    val_x_encoded_list.append(X_val_enc)
    test_x_encoded_list.append(X_test_enc)

print("Encoding (One-Hot + TargetEncoding) for all list entries completed.")
# Out:
# [0] fitting encoder on train_x_list[0] with onehot: ['fuelType', 'transmission', 'model'] and target-enc: ['fuelType', 'transmission', 'model']
#
# [1] fitting encoder on train_x_list[1] with onehot: ['fuelType', 'transmission', 'model'] and target-enc: ['fuelType', 'transmission', 'model']
#
# [2] fitting encoder on train_x_list[2] with onehot: ['fuelType', 'transmission', 'model'] and target-enc: ['fuelType', 'transmission', 'model']
#
# [3] fitting encoder on train_x_list[3] with onehot: ['fuelType', 'transmission', 'model'] and target-enc: ['fuelType', 'transmission', 'model']
#
# [4] fitting encoder on train_x_list[4] with onehot: ['fuelType', 'transmission', 'model'] and target-enc: ['fuelType', 'transmission', 'model']
#
# [5] fitting encoder on train_x_list[5] with onehot: ['fuelType', 'transmission', 'model'] and target-enc: ['fuelType', 'transmission', 'model']
#
# [6] fitting encoder on train_x_list[6] with onehot: ['fuelType', 'transmission', 'model'] and target-enc: ['fuelType', 'transmission', 'model']
#
# [7] fitting encoder on train_x_list[7] with onehot: ['fuelType', 'transmission', 'model'] and target-enc: ['fuelType', 'transmission', 'model']
#
# [8] fitting encoder on train_x_list[8] with onehot: ['fuelType', 'transmission', 'model'] and target-enc: ['fuelType', 'transmission', 'model']
# Encoding (One-Hot + TargetEncoding) für alle Listeneinträge fertig.

# %% [markdown]
# We replace our original lists with the encoded ones.

# %%
train_x_list = train_x_encoded_list
val_x_list   = val_x_encoded_list
test_x_list  = test_x_encoded_list

# %% [markdown]
# <a id="sec-4-filter"></a>
# ## 8. Feature Selection

# %% [markdown]
# For Feature Selection we first use filter methods and then use wrapper methods.

# %% [markdown]
# <a id="sec-4-filter"></a>
# ### 8.1 Filter Methods

# %% [markdown]
# We start with Filter methods, because they are computationally inexpensive and helpful for an initial screening of features.

# %% [markdown]
# <a id="sec-4-1-variance"></a>
# #### 8.1.1 Variance Threshold (Constant or Quasi-constant)

# %% [markdown]
# We therefore first calculate the variance, since values that are always the same dont help us with predicting.

# %%
# compute population variance, round for readability, sort by variance desc

train_x_list[0].var(ddof=0).round(6).sort_values(ascending=False)
# Out:
# mileage                        3.943445e+08
# mileage_per_year               1.728025e+08
# model                          6.894463e+06
# transmission                   1.392612e+06
# fuelType                       5.125049e+05
# tax                            3.921508e+03
# efficiency_ratio               1.503677e+02
# mpg                            9.458995e+01
# mpg_diff_transmission          9.011871e+01
# car_age                        4.379981e+00
# year                           4.379981e+00
# previousOwners                 2.036174e+00
# model_Focus                    2.463780e-01
# fuelType_Petrol                2.181100e-01
# fuelType_Diesel                2.178220e-01
# model_Fiesta                   1.989810e-01
# high_mileage_flag              1.875180e-01
# engineSize                     1.820000e-01
# transmission_Manual            1.155520e-01
# very_high_mileage_flag         8.989500e-02
# model_Kuga                     8.386200e-02
# transmission_Automatic         7.478900e-02
# transmission_Semi-Auto         4.921600e-02
# model_EcoSport                 4.770400e-02
# model_C-MAX                    2.302000e-02
# model_Ka+                      2.232200e-02
# model_Mondeo                   2.127300e-02
# hasDamage                      1.923700e-02
# model_B-MAX                    1.492600e-02
# model_S-MAX                    1.157800e-02
# model_Ka                       9.499000e-03
# model_Grand C-MAX              8.781000e-03
# model_Galaxy                   8.421000e-03
# model_Edge                     8.205000e-03
# model_Puma                     3.211000e-03
# model_Tourneo Custom           2.847000e-03
# model_Grand Tourneo Connect    2.556000e-03
# model_Mustang                  2.337000e-03
# model_Other                    2.192000e-03
# fuelType_Hybrid                7.320000e-04
# fuelType_Electric              7.300000e-05
# dtype: float64

# %% [markdown]
# We can see that some Features have a very low variance. We will set a threshold of 0.001 to remove features with variance below this value.

# %%
for i in range(len(train_x_list)):

    # Drop features from training data that have very low variance
    # threshold=0.001 means features with near-constant values are removed
    train_x_list[i], dropped_features = drop_low_variance_features(train_x_list[i], threshold=0.001)

    # Drop the same low-variance features from validation and test sets
    # Ensures all splits have the same feature set
    val_x_list[i] = val_x_list[i].drop(columns=dropped_features)
    test_x_list[i] = test_x_list[i].drop(columns=dropped_features)

    # Print the features that were removed
    print(f"Dropped low-variance features: {list(dropped_features)}")
# Out:
# Dropped low-variance features: ['fuelType_Electric', 'fuelType_Hybrid']
# Dropped low-variance features: ['fuelType_Other', 'transmission_Other']
# Dropped low-variance features: []
# Dropped low-variance features: ['fuelType_Electric', 'fuelType_Other', 'transmission_Other']
# Dropped low-variance features: ['fuelType_Electric']
# Dropped low-variance features: []
# Dropped low-variance features: []
# Dropped low-variance features: ['transmission_Other']
# Dropped low-variance features: ['fuelType_Other', 'transmission_Other']

# %% [markdown]
# <a id="sec-4-2-correlation"></a>
# #### 8.1.1 Correlation Analysis
# We decided us to not use Correlation Analysis, because it does not help our model.

# %% [markdown]
# <a id="sec-5-wrapper"></a>
# ### 8.2 Wrapper Method: Permutation-based Feature Selection

# %% [markdown]
# Instead of Recursive Feature Elimination (RFE), we use a permutation-importance
# wrapper method with a Random Forest:
#
# - For each brand, we train a `RandomForestRegressor` on all features of the
#    training split.
# - We compute permutation importance on the corresponding validation split
#    (using R² as the scoring metric). This measures how much the model’s
#    performance drops when a feature is randomly shuffled.
# - We rank all features by their mean permutation importance and drop the
#    bottom 15% (the least important ones). If the 0.15 Quantile is a negative value (bad for the model), we drop every feature that is negative or zero (more than 15%). If the 0.15 Quantile is bigger than 0.0001 it only drops values up to this threshold, so that we don't cut features that could help us.

# %%
# %%time
Q = 0.15  # quantile threshold for feature selection
for i in range(len(train_x_list)):

    # 1) Train a Random Forest on all current features
rf = RandomForestRegressor(
    n_estimators=300,      # Number of decision trees in the forest
                            # low value  more stable and accurate predictions (reduces variance)
                            # high trees  longer training time, more memory usage

    random_state=42,       # Seed for reproducibility
                            # + Ensures results are consistent across runs (important for debugging and analysis)
                            # - No downside; purely for deterministic behavior

    n_jobs=1,              # Number of CPU cores used for training
                            # + 1 core → less memory consumption and avoids spikes (useful on limited-memory machines)
                            # - Slower than using multiple cores (-1), but safer for stability in feature importance calculations

    max_features="sqrt"    # Number of features to consider at each split
                            # + Using sqrt(n_features) decorrelates trees → reduces overfitting, better generalization
                            # + Speeds up training compared to considering all features
                            # - Might slightly underfit if too few features are considered at each split
)

    rf.fit(train_x_list[i], train_y_list[i])

    # 2) Compute permutation importance on the validation set
    # Measures how much each feature contributes to R^2 on unseen data
    perm = permutation_importance(
        rf,
        val_x_list[i],
        val_y_list[i],
        n_repeats=20,          # repeat for stability
        random_state=42,
        scoring="r2",
        n_jobs=-1              # parallel computation for speed
    )

    # Average importance across repeats
    imp_mean = pd.Series(
        perm.importances_mean,
        index=train_x_list[i].columns
    ).sort_values(ascending=False)

    # 15th percentile of importance values
    q15 = imp_mean.quantile(Q)

    # Decide which features to keep based on threshold logic
    if q15 > 0.0001:
        threshold = 0.0001
        selected_feats = imp_mean[imp_mean > threshold].index.tolist()
        dropped_feats  = imp_mean[imp_mean <= threshold].index.tolist()
        rule = "drop<=0.0001"
    elif q15 > 0:
        threshold = q15
        selected_feats = imp_mean[imp_mean >= threshold].index.tolist()
        dropped_feats  = imp_mean[imp_mean <  threshold].index.tolist()
        rule = f"quantile@{Q:.2f}"
    else:
        threshold = 0.0
        selected_feats = imp_mean[imp_mean > threshold].index.tolist()
        dropped_feats  = imp_mean[imp_mean <= threshold].index.tolist()
        rule = "drop<=0"

    # Print summary for transparency
    print(f"\nBrand {i}: start={train_x_list[i].shape[1]}  "
          f"kept={len(selected_feats)}  dropped={len(dropped_feats)}  "
          f"q15={q15:.6f}  rule={rule}  thr={threshold:.6f}")

    # 3) Keep only the selected features in all splits
    train_x_list[i] = train_x_list[i][selected_feats]
    val_x_list[i]   = val_x_list[i][selected_feats]
    test_x_list[i]  = test_x_list[i][selected_feats]

    # Store for downstream RF modeling
    rf_train_x_list = train_x_list
    rf_val_x_list   = val_x_list
    rf_test_x_list  = test_x_list

    rf_train_y_list = train_y_list
    rf_val_y_list   = val_y_list
# Out:
# Brand 0: start=39  kept=33  dropped=6  q15=0.000050  rule=quantile@0.15  thr=0.000050
#
# Brand 1: start=41  kept=35  dropped=6  q15=0.000112  rule=drop<=0.0001  thr=0.000100
#
# Brand 2: start=45  kept=38  dropped=7  q15=0.000009  rule=quantile@0.15  thr=0.000009
#
# Brand 3: start=36  kept=29  dropped=7  q15=-0.000057  rule=drop<=0  thr=0.000000
#
# Brand 4: start=42  kept=36  dropped=6  q15=0.000118  rule=drop<=0.0001  thr=0.000100
#
# Brand 5: start=38  kept=32  dropped=6  q15=0.000054  rule=quantile@0.15  thr=0.000054
#
# Brand 6: start=36  kept=31  dropped=5  q15=0.000112  rule=drop<=0.0001  thr=0.000100
#
# Brand 7: start=35  kept=29  dropped=6  q15=0.000062  rule=quantile@0.15  thr=0.000062
#
# Brand 8: start=34  kept=29  dropped=5  q15=0.000057  rule=quantile@0.15  thr=0.000057
# CPU times: total: 8min 49s
# Wall time: 15min 54s

# %%
best_params_per_brand_et = [
    # Brand 0
    {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5,
     'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 800},

    # Brand 1
    {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5,
     'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 1200},

    # Brand 2
    {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5,
     'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 800},

    # Brand 3
    {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt',
     'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 1200},

    # Brand 4
    {'bootstrap': False, 'max_depth': None, 'max_features': 0.5,
     'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 1200},

    # Brand 5
    {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5,
     'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 1200},

    # Brand 6
    {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5,
     'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 500},

    # Brand 7
    {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5,
     'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 1200},

    # Brand 8
    {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5,
     'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 1200}]

Q = 0.15

for i in range(len(train_x_list)):

    # 1) train on ALL features (ExtraTrees with your tuned params)
    et = ExtraTreesRegressor(
        random_state=42,
        n_jobs=-1,
        **best_params_per_brand_et[i]
    )
    et.fit(train_x_list[i], train_y_list[i])

    # 2) permutation importance on val
    perm = permutation_importance(
        et,
        val_x_list[i],
        val_y_list[i],
        n_repeats=20,
        random_state=42,
        scoring="r2",
        n_jobs=-1
    )

    imp_mean = pd.Series(
        perm.importances_mean,
        index=train_x_list[i].columns
    ).sort_values(ascending=False)

    # 3) decision rule:
    # - if q15 > 0: do quantile cut (like before)
    # - else: drop everything with importance <= 0
    q15 = imp_mean.quantile(Q)

    if q15 > 0.0001:
        threshold = 0.0001
        selected_feats = imp_mean[imp_mean > threshold].index.tolist()
        dropped_feats  = imp_mean[imp_mean <= threshold].index.tolist()
        rule = "drop<=0.0001"
    elif q15 > 0:
        threshold = q15
        selected_feats = imp_mean[imp_mean >= threshold].index.tolist()
        dropped_feats  = imp_mean[imp_mean <  threshold].index.tolist()
        rule = f"quantile@{Q:.2f}"
    else:
        threshold = 0.0
        selected_feats = imp_mean[imp_mean > threshold].index.tolist()
        dropped_feats  = imp_mean[imp_mean <= threshold].index.tolist()
        rule = "drop<=0"

    print(f"\nBrand {i}: start={train_x_list[i].shape[1]}  "
          f"kept={len(selected_feats)}  dropped={len(dropped_feats)}  "
          f"q15={q15:.6f}  rule={rule}  thr={threshold:.6f}")

    # update
    train_x_list[i] = train_x_list[i][selected_feats]
    val_x_list[i]   = val_x_list[i][selected_feats]
    test_x_list[i]  = test_x_list[i][selected_feats]
# Out:
# Brand 0: start=33  kept=28  dropped=5  q15=0.000143  rule=drop<=0.0001  thr=0.000100
#
# Brand 1: start=35  kept=34  dropped=1  q15=0.000562  rule=drop<=0.0001  thr=0.000100
#
# Brand 2: start=38  kept=32  dropped=6  q15=0.000043  rule=quantile@0.15  thr=0.000043
#
# Brand 3: start=29  kept=28  dropped=1  q15=0.001810  rule=drop<=0.0001  thr=0.000100
#
# Brand 4: start=36  kept=35  dropped=1  q15=0.000601  rule=drop<=0.0001  thr=0.000100
#
# Brand 5: start=32  kept=27  dropped=5  q15=0.000121  rule=drop<=0.0001  thr=0.000100
#
# Brand 6: start=31  kept=30  dropped=1  q15=0.000651  rule=drop<=0.0001  thr=0.000100
#
# Brand 7: start=29  kept=29  dropped=0  q15=0.000588  rule=drop<=0.0001  thr=0.000100
#
# Brand 8: start=29  kept=26  dropped=3  q15=0.000737  rule=drop<=0.0001  thr=0.000100

# %% [markdown]
# ## 9. Models

# %% [markdown]
# For models we tried Random Forest Regressor, Extra Tree Regressor and Hist Gradient Boosting Regressor. For each of those we use grid search and hardcode the result to be able to faster test the models.

# %% [markdown]
# ### 9.1 Random Forest Regressor

# %% [markdown]
# First we use grid search for Random Forest.

# %%
param_grid = {
    "n_estimators": [200, 300, 400, 500, 600],
    "max_depth": [15, 17, 20, 23, 25],
    "max_features": ["sqrt", 0.5],
    "min_samples_split": [3, 5, 7],
    "min_samples_leaf": [1, 2],
}

grid = list(ParameterGrid(param_grid))
n_total = len(grid)

best_params_per_brand_rf = []
best_score_per_brand_rf = []

for b in range(len(train_x_list)):
    Xtr = rf_train_x_list[b]
    ytr = rf_train_y_list[b]
    Xva = val_x_list[b]
    yva = val_y_list[b]

    best_mae = float("inf")
    best_params = None

    print("\n==============================")
    print(f"Brand {b}: grid search over {n_total} configs")

    for i, params in enumerate(grid, start=1):
        print(f"[{i}/{n_total}] params: {params}")

        model = RandomForestRegressor(**params, random_state=42, n_jobs=-1)
        model.fit(Xtr, ytr)

        pred = model.predict(Xva)
        mae = mean_absolute_error(yva, pred)

        print(f"    -> MAE: {mae:.3f}")

        if mae < best_mae:
            best_mae = mae
            best_params = params
            print(f"    NEW BEST: MAE={best_mae:.3f} | params={best_params}")

    best_params_per_brand_rf.append(best_params)
    best_score_per_brand_rf.append(best_mae)

print("\n===== FINAL BEST PER BRAND =====")
for b, (p, s) in enumerate(zip(best_params_per_brand_rf, best_score_per_brand_rf)):
    print(f"Brand {b}: MAE={s:.3f} | params={p}")
# Out:
# ==============================
# Brand 0: grid search over 300 configs
# [1/300] params: {'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 200}
#     -> MAE: 927.070
#     NEW BEST: MAE=927.070 | params={'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 200}
# [2/300] params: {'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 300}
#     -> MAE: 925.244
#     NEW BEST: MAE=925.244 | params={'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 300}
# [3/300] params: {'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 400}
#     -> MAE: 924.535
#     NEW BEST: MAE=924.535 | params={'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 400}
# [4/300] params: {'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE: 924.429
#     NEW BEST: MAE=924.429 | params={'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 500}
# [5/300] params: {'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 600}
#     -> MAE: 924.144
#     NEW BEST: MAE=924.144 | params={'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 600}
# [6/300] params: {'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200}
#     -> MAE: 925.634
# [7/300] params: {'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 300}
#     -> MAE: 925.685
# [8/300] params: {'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 400}
#     -> MAE: 926.214
# [9/300] params: {'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE: 925.254
# [10/300] params: {'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 600}
#     -> MAE: 924.733
# [11/300] params: {'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 200}
#     -> MAE: 931.321
# [12/300] params: {'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 300}
#     -> MAE: 929.020
# [13/300] params: {'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 400}
#     -> MAE: 928.750
# [14/300] params: {'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 500}
#     -> MAE: 928.170
# [15/300] params: {'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 600}
#     -> MAE: 927.953
# [16/300] params: {'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 200}
#     -> MAE: 935.884
# [17/300] params: {'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 300}
#     -> MAE: 934.356
# [18/300] params: {'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 400}
#     -> MAE: 934.793
# [19/300] params: {'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE: 934.483
# [20/300] params: {'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 600}
#     -> MAE: 934.273
# [21/300] params: {'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
#     -> MAE: 938.631
# [22/300] params: {'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 300}
#     -> MAE: 937.945
# [23/300] params: {'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 400}
#     -> MAE: 937.548
# [24/300] params: {'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE: 936.993
# [25/300] params: {'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 600}
#     -> MAE: 936.496
# [26/300] params: {'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 200}
#     -> MAE: 938.836
# [27/300] params: {'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 300}
#     -> MAE: 937.781
# [28/300] params: {'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 400}
#     -> MAE: 936.577
# [29/300] params: {'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 500}
#     -> MAE: 936.637
# [30/300] params: {'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 600}
#     -> MAE: 936.251
# [31/300] params: {'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 200}
#     -> MAE: 916.298
#     NEW BEST: MAE=916.298 | params={'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 200}
# [32/300] params: {'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 300}
#     -> MAE: 916.360
# [33/300] params: {'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 400}
#     -> MAE: 915.510
#     NEW BEST: MAE=915.510 | params={'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 400}
# [34/300] params: {'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE: 915.099
#     NEW BEST: MAE=915.099 | params={'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 500}
# [35/300] params: {'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 600}
#     -> MAE: 915.283
# [36/300] params: {'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200}
#     -> MAE: 914.829
#     NEW BEST: MAE=914.829 | params={'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200}
# [37/300] params: {'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 300}
#     -> MAE: 914.076
#     NEW BEST: MAE=914.076 | params={'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 300}
# [38/300] params: {'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 400}
#     -> MAE: 914.135
# [39/300] params: {'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE: 913.518
#     NEW BEST: MAE=913.518 | params={'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 500}
# [40/300] params: {'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 600}
#     -> MAE: 913.236
#     NEW BEST: MAE=913.236 | params={'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 600}
# [41/300] params: {'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 200}
#     -> MAE: 915.427
# [42/300] params: {'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 300}
#     -> MAE: 915.741
# [43/300] params: {'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 400}
#     -> MAE: 915.440
# [44/300] params: {'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 500}
#     -> MAE: 915.045
# [45/300] params: {'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 600}
#     -> MAE: 915.445
# [46/300] params: {'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 200}
#     -> MAE: 922.259
# [47/300] params: {'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 300}
#     -> MAE: 922.674
# [48/300] params: {'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 400}
#     -> MAE: 922.477
# [49/300] params: {'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE: 922.000
# [50/300] params: {'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 600}
#     -> MAE: 921.790
# [51/300] params: {'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
#     -> MAE: 921.781
# [52/300] params: {'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 300}
#     -> MAE: 922.437
# [53/300] params: {'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 400}
#     -> MAE: 922.345
# [54/300] params: {'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE: 922.202
# [55/300] params: {'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 600}
#     -> MAE: 922.509
# [56/300] params: {'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 200}
#     -> MAE: 924.331
# [57/300] params: {'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 300}
#     -> MAE: 924.339
# [58/300] params: {'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 400}
#     -> MAE: 924.554
# [59/300] params: {'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 500}
#     -> MAE: 923.599
# [60/300] params: {'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 600}
#     -> MAE: 923.685
# [61/300] params: {'max_depth': 17, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 200}
#     -> MAE: 927.978
# [62/300] params: {'max_depth': 17, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 300}
#     -> MAE: 926.995
# [63/300] params: {'max_depth': 17, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 400}
#     -> MAE: 926.354
# [64/300] params: {'max_depth': 17, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE: 924.620
# [65/300] params: {'max_depth': 17, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 600}
#     -> MAE: 924.586
# [66/300] params: {'max_depth': 17, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200}
#     -> MAE: 924.478
# [67/300] params: {'max_depth': 17, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 300}
#     -> MAE: 923.422
# [68/300] params: {'max_depth': 17, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 400}
#     -> MAE: 923.426
# [69/300] params: {'max_depth': 17, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE: 922.712
# [70/300] params: {'max_depth': 17, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 600}
#     -> MAE: 922.642
# [71/300] params: {'max_depth': 17, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 200}
#     -> MAE: 924.847
# [72/300] params: {'max_depth': 17, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 300}
#     -> MAE: 923.774
# [73/300] params: {'max_depth': 17, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 400}
#     -> MAE: 923.334
# [74/300] params: {'max_depth': 17, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 500}
#     -> MAE: 922.970
# [75/300] params: {'max_depth': 17, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 600}
#     -> MAE: 922.752
# [76/300] params: {'max_depth': 17, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 200}
#     -> MAE: 932.807
# [77/300] params: {'max_depth': 17, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 300}
#     -> MAE: 932.399
# [78/300] params: {'max_depth': 17, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 400}
#     -> MAE: 931.678
# [79/300] params: {'max_depth': 17, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE: 931.020
# [80/300] params: {'max_depth': 17, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 600}
#     -> MAE: 930.783
# [81/300] params: {'max_depth': 17, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
#     -> MAE: 932.839
# [82/300] params: {'max_depth': 17, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 300}
#     -> MAE: 932.913
# [83/300] params: {'max_depth': 17, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 400}
#     -> MAE: 932.744
# [84/300] params: {'max_depth': 17, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE: 931.678
# [85/300] params: {'max_depth': 17, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 600}
#     -> MAE: 931.165
# [86/300] params: {'max_depth': 17, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 200}
#     -> MAE: 935.195
# [87/300] params: {'max_depth': 17, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 300}
#     -> MAE: 933.240
# [88/300] params: {'max_depth': 17, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 400}
#     -> MAE: 932.737
# [89/300] params: {'max_depth': 17, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 500}
#     -> MAE: 932.560
# [90/300] params: {'max_depth': 17, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 600}
#     -> MAE: 932.683
# [91/300] params: {'max_depth': 17, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 200}
#     -> MAE: 918.844
# [92/300] params: {'max_depth': 17, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 300}
#     -> MAE: 918.808
# [93/300] params: {'max_depth': 17, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 400}
#     -> MAE: 917.446
# [94/300] params: {'max_depth': 17, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE: 917.416
# [95/300] params: {'max_depth': 17, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 600}
#     -> MAE: 917.491
# [96/300] params: {'max_depth': 17, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200}
#     -> MAE: 917.752
# [97/300] params: {'max_depth': 17, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 300}
#     -> MAE: 917.189
# [98/300] params: {'max_depth': 17, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 400}
#     -> MAE: 915.749
# [99/300] params: {'max_depth': 17, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE: 915.311
# [100/300] params: {'max_depth': 17, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 600}
#     -> MAE: 914.591
# [101/300] params: {'max_depth': 17, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 200}
#     -> MAE: 914.357
# [102/300] params: {'max_depth': 17, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 300}
#     -> MAE: 914.489
# [103/300] params: {'max_depth': 17, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 400}
#     -> MAE: 914.198
# [104/300] params: {'max_depth': 17, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 500}
#     -> MAE: 914.381
# [105/300] params: {'max_depth': 17, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 600}
#     -> MAE: 914.723
# [106/300] params: {'max_depth': 17, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 200}
#     -> MAE: 926.205
# [107/300] params: {'max_depth': 17, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 300}
#     -> MAE: 925.423
# [108/300] params: {'max_depth': 17, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 400}
#     -> MAE: 924.078
# [109/300] params: {'max_depth': 17, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE: 923.101
# [110/300] params: {'max_depth': 17, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 600}
#     -> MAE: 923.097
# [111/300] params: {'max_depth': 17, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
#     -> MAE: 922.515
# [112/300] params: {'max_depth': 17, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 300}
#     -> MAE: 923.066
# [113/300] params: {'max_depth': 17, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 400}
#     -> MAE: 921.367
# [114/300] params: {'max_depth': 17, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE: 921.326
# [115/300] params: {'max_depth': 17, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 600}
#     -> MAE: 921.418
# [116/300] params: {'max_depth': 17, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 200}
#     -> MAE: 924.900
# [117/300] params: {'max_depth': 17, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 300}
#     -> MAE: 924.317
# [118/300] params: {'max_depth': 17, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 400}
#     -> MAE: 924.257
# [119/300] params: {'max_depth': 17, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 500}
#     -> MAE: 923.380
# [120/300] params: {'max_depth': 17, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 600}
#     -> MAE: 923.765
# [121/300] params: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 200}
#     -> MAE: 933.120
# [122/300] params: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 300}
#     -> MAE: 930.767
# [123/300] params: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 400}
#     -> MAE: 931.096
# [124/300] params: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE: 929.752
# [125/300] params: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 600}
#     -> MAE: 929.086
# [126/300] params: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200}
#     -> MAE: 927.030
# [127/300] params: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 300}
#     -> MAE: 927.313
# [128/300] params: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 400}
#     -> MAE: 927.675
# [129/300] params: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE: 927.571
# [130/300] params: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 600}
#     -> MAE: 927.036
# [131/300] params: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 200}
#     -> MAE: 928.098
# [132/300] params: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 300}
#     -> MAE: 927.356
# [133/300] params: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 400}
#     -> MAE: 927.406
# [134/300] params: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 500}
#     -> MAE: 926.663
# [135/300] params: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 600}
#     -> MAE: 926.130
# [136/300] params: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 200}
#     -> MAE: 933.011
# [137/300] params: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 300}
#     -> MAE: 933.530
# [138/300] params: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 400}
#     -> MAE: 932.003
# [139/300] params: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE: 931.820
# [140/300] params: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 600}
#     -> MAE: 931.864
# [141/300] params: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
#     -> MAE: 935.113
# [142/300] params: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 300}
#     -> MAE: 934.352
# [143/300] params: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 400}
#     -> MAE: 932.822
# [144/300] params: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE: 933.101
# [145/300] params: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 600}
#     -> MAE: 932.340
# [146/300] params: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 200}
#     -> MAE: 935.220
# [147/300] params: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 300}
#     -> MAE: 934.623
# [148/300] params: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 400}
#     -> MAE: 933.711
# [149/300] params: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 500}
#     -> MAE: 932.864
# [150/300] params: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 600}
#     -> MAE: 933.179
# [151/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 200}
#     -> MAE: 927.851
# [152/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 300}
#     -> MAE: 927.728
# [153/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 400}
#     -> MAE: 927.981
# [154/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE: 927.081
# [155/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 600}
#     -> MAE: 926.154
# [156/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200}
#     -> MAE: 922.361
# [157/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 300}
#     -> MAE: 921.717
# [158/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 400}
#     -> MAE: 920.039
# [159/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE: 919.812
# [160/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 600}
#     -> MAE: 919.768
# [161/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 200}
#     -> MAE: 918.890
# [162/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 300}
#     -> MAE: 919.737
# [163/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 400}
#     -> MAE: 919.730
# [164/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 500}
#     -> MAE: 919.275
# [165/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 600}
#     -> MAE: 919.079
# [166/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 200}
#     -> MAE: 928.620
# [167/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 300}
#     -> MAE: 928.090
# [168/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 400}
#     -> MAE: 927.892
# [169/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE: 927.716
# [170/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 600}
#     -> MAE: 928.017
# [171/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
#     -> MAE: 926.016
# [172/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 300}
#     -> MAE: 927.028
# [173/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 400}
#     -> MAE: 925.320
# [174/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE: 925.377
# [175/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 600}
#     -> MAE: 926.503
# [176/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 200}
#     -> MAE: 926.491
# [177/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 300}
#     -> MAE: 926.757
# [178/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 400}
#     -> MAE: 925.950
# [179/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 500}
#     -> MAE: 925.682
# [180/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 600}
#     -> MAE: 925.828
# [181/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 200}
#     -> MAE: 943.673
# [182/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 300}
#     -> MAE: 943.235
# [183/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 400}
#     -> MAE: 941.527
# [184/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE: 940.449
# [185/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 600}
#     -> MAE: 939.922
# [186/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200}
#     -> MAE: 933.635
# [187/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 300}
#     -> MAE: 933.690
# [188/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 400}
#     -> MAE: 932.504
# [189/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE: 932.815
# [190/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 600}
#     -> MAE: 932.508
# [191/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 200}
#     -> MAE: 931.960
# [192/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 300}
#     -> MAE: 931.883
# [193/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 400}
#     -> MAE: 930.262
# [194/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 500}
#     -> MAE: 929.828
# [195/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 600}
#     -> MAE: 929.203
# [196/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 200}
#     -> MAE: 934.638
# [197/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 300}
#     -> MAE: 934.543
# [198/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 400}
#     -> MAE: 933.232
# [199/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE: 932.701
# [200/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 600}
#     -> MAE: 932.784
# [201/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
#     -> MAE: 931.118
# [202/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 300}
#     -> MAE: 931.907
# [203/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 400}
#     -> MAE: 931.807
# [204/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE: 932.341
# [205/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 600}
#     -> MAE: 931.927
# [206/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 200}
#     -> MAE: 937.000
# [207/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 300}
#     -> MAE: 936.614
# [208/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 400}
#     -> MAE: 936.072
# [209/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 500}
#     -> MAE: 934.782
# [210/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 600}
#     -> MAE: 935.237
# [211/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 200}
#     -> MAE: 928.474
# [212/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 300}
#     -> MAE: 929.901
# [213/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 400}
#     -> MAE: 929.602
# [214/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE: 928.657
# [215/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 600}
#     -> MAE: 928.485
# [216/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200}
#     -> MAE: 925.130
# [217/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 300}
#     -> MAE: 924.859
# [218/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 400}
#     -> MAE: 924.879
# [219/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE: 923.699
# [220/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 600}
#     -> MAE: 923.430
# [221/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 200}
#     -> MAE: 922.367
# [222/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 300}
#     -> MAE: 922.127
# [223/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 400}
#     -> MAE: 920.824
# [224/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 500}
#     -> MAE: 920.534
# [225/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 600}
#     -> MAE: 921.011
# [226/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 200}
#     -> MAE: 930.025
# [227/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 300}
#     -> MAE: 929.689
# [228/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 400}
#     -> MAE: 929.260
# [229/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE: 928.715
# [230/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 600}
#     -> MAE: 929.701
# [231/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
#     -> MAE: 928.887
# [232/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 300}
#     -> MAE: 929.425
# [233/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 400}
#     -> MAE: 927.666
# [234/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE: 927.385
# [235/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 600}
#     -> MAE: 928.084
# [236/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 200}
#     -> MAE: 929.425
# [237/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 300}
#     -> MAE: 929.153
# [238/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 400}
#     -> MAE: 929.331
# [239/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 500}
#     -> MAE: 928.672
# [240/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 600}
#     -> MAE: 928.679
# [241/300] params: {'max_depth': 25, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 200}
#     -> MAE: 946.048
# [242/300] params: {'max_depth': 25, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 300}
#     -> MAE: 945.218
# [243/300] params: {'max_depth': 25, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 400}
#     -> MAE: 944.980
# [244/300] params: {'max_depth': 25, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE: 943.020
# [245/300] params: {'max_depth': 25, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 600}
#     -> MAE: 943.183
# [246/300] params: {'max_depth': 25, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200}
#     -> MAE: 937.071
# [247/300] params: {'max_depth': 25, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 300}
#     -> MAE: 935.010
# [248/300] params: {'max_depth': 25, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 400}
#     -> MAE: 934.880
# [249/300] params: {'max_depth': 25, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE: 934.085
# [250/300] params: {'max_depth': 25, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 600}
#     -> MAE: 933.733
# [251/300] params: {'max_depth': 25, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 200}
#     -> MAE: 932.429
# [252/300] params: {'max_depth': 25, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 300}
#     -> MAE: 932.190
# [253/300] params: {'max_depth': 25, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 400}
#     -> MAE: 932.264
# [254/300] params: {'max_depth': 25, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 500}
#     -> MAE: 930.936
# [255/300] params: {'max_depth': 25, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 600}
#     -> MAE: 930.688
# [256/300] params: {'max_depth': 25, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 200}
#     -> MAE: 935.801
# [257/300] params: {'max_depth': 25, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 300}
#     -> MAE: 934.917
# [258/300] params: {'max_depth': 25, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 400}
#     -> MAE: 935.129
# [259/300] params: {'max_depth': 25, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE: 934.919
# [260/300] params: {'max_depth': 25, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 600}
#     -> MAE: 935.656
# [261/300] params: {'max_depth': 25, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
#     -> MAE: 935.778
# [262/300] params: {'max_depth': 25, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 300}
#     -> MAE: 935.134
# [263/300] params: {'max_depth': 25, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 400}
#     -> MAE: 933.870
# [264/300] params: {'max_depth': 25, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE: 933.182
# [265/300] params: {'max_depth': 25, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 600}
#     -> MAE: 932.475
# [266/300] params: {'max_depth': 25, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 200}
#     -> MAE: 939.631
# [267/300] params: {'max_depth': 25, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 300}
#     -> MAE: 940.179
# [268/300] params: {'max_depth': 25, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 400}
#     -> MAE: 938.812
# [269/300] params: {'max_depth': 25, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 500}
#     -> MAE: 937.787
# [270/300] params: {'max_depth': 25, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 600}
#     -> MAE: 936.864
# [271/300] params: {'max_depth': 25, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 200}
#     -> MAE: 929.572
# [272/300] params: {'max_depth': 25, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 300}
#     -> MAE: 930.263
# [273/300] params: {'max_depth': 25, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 400}
#     -> MAE: 930.687
# [274/300] params: {'max_depth': 25, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE: 930.100
# [275/300] params: {'max_depth': 25, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 600}
#     -> MAE: 930.475
# [276/300] params: {'max_depth': 25, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200}
#     -> MAE: 921.320
# [277/300] params: {'max_depth': 25, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 300}
#     -> MAE: 923.342
# [278/300] params: {'max_depth': 25, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 400}
#     -> MAE: 923.256
# [279/300] params: {'max_depth': 25, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE: 923.437
# [280/300] params: {'max_depth': 25, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 600}
#     -> MAE: 923.687
# [281/300] params: {'max_depth': 25, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 200}
#     -> MAE: 923.048
# [282/300] params: {'max_depth': 25, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 300}
#     -> MAE: 923.185
# [283/300] params: {'max_depth': 25, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 400}
#     -> MAE: 921.592
# [284/300] params: {'max_depth': 25, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 500}
#     -> MAE: 922.151
# [285/300] params: {'max_depth': 25, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 600}
#     -> MAE: 921.310
# [286/300] params: {'max_depth': 25, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 200}
#     -> MAE: 931.089
# [287/300] params: {'max_depth': 25, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 300}
#     -> MAE: 930.599
# [288/300] params: {'max_depth': 25, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 400}
#     -> MAE: 929.909
# [289/300] params: {'max_depth': 25, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE: 929.703
# [290/300] params: {'max_depth': 25, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 600}
#     -> MAE: 929.455
# [291/300] params: {'max_depth': 25, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
#     -> MAE: 931.711
# [292/300] params: {'max_depth': 25, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 300}
#     -> MAE: 930.807
# [293/300] params: {'max_depth': 25, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 400}
#     -> MAE: 929.277
# [294/300] params: {'max_depth': 25, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE: 928.796
# [295/300] params: {'max_depth': 25, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 600}
#     -> MAE: 929.665
# [296/300] params: {'max_depth': 25, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 200}
#     -> MAE: 927.003
# [297/300] params: {'max_depth': 25, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 300}
#     -> MAE: 927.760
# [298/300] params: {'max_depth': 25, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 400}
#     -> MAE: 927.300
# [299/300] params: {'max_depth': 25, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 500}
#     -> MAE: 926.956
# [300/300] params: {'max_depth': 25, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 600}
#     -> MAE: 926.151
#
# ==============================
# Brand 1: grid search over 300 configs
# [1/300] params: {'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 200}
#     -> MAE: 1798.420
#     NEW BEST: MAE=1798.420 | params={'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 200}
# [2/300] params: {'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 300}
#     -> MAE: 1800.422
# [3/300] params: {'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 400}
#     -> MAE: 1795.012
#     NEW BEST: MAE=1795.012 | params={'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 400}
# [4/300] params: {'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE: 1794.976
#     NEW BEST: MAE=1794.976 | params={'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 500}
# [5/300] params: {'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 600}
#     -> MAE: 1794.108
#     NEW BEST: MAE=1794.108 | params={'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 600}
# [6/300] params: {'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200}
#     -> MAE: 1811.556
# [7/300] params: {'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 300}
#     -> MAE: 1813.449
# [8/300] params: {'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 400}
#     -> MAE: 1811.254
# [9/300] params: {'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE: 1810.608
# [10/300] params: {'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 600}
#     -> MAE: 1809.374
# [11/300] params: {'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 200}
#     -> MAE: 1827.631
# ...
#     -> MAE: 841.328
# [131/300] params: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 200}
#     -> MAE: 844.028
# [132/300] params: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 300}
#     -> MAE: 843.059
# [133/300] params: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 400}
#     -> MAE: 841.225
# [134/300] params: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 500}
#     -> MAE: 844.809
# [135/300] params: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 600}
#     -> MAE: 843.205
# [136/300] params: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 200}
#     -> MAE: 852.446
# [137/300] params: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 300}
#     -> MAE: 849.973
# [138/300] params: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 400}
#     -> MAE: 849.872
# [139/300] params: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE: 850.602
# [140/300] params: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 600}
#     -> MAE: 849.362
# [141/300] params: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
#     -> MAE: 850.907
# [142/300] params: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 300}
#     -> MAE: 850.807
# [143/300] params: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 400}
#     -> MAE: 849.127
# [144/300] params: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE: 849.252
# [145/300] params: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 600}
#     -> MAE: 848.532
# [146/300] params: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 200}
#     -> MAE: 852.156
# [147/300] params: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 300}
#     -> MAE: 857.859
# [148/300] params: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 400}
#     -> MAE: 856.302
# [149/300] params: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 500}
#     -> MAE: 858.727
# [150/300] params: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 600}
#     -> MAE: 857.717
# [151/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 200}
#     -> MAE: 838.313
# [152/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 300}
#     -> MAE: 838.145
# [153/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 400}
#     -> MAE: 839.226
# [154/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE: 839.935
# [155/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 600}
#     -> MAE: 839.172
# [156/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200}
#     -> MAE: 832.168
# [157/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 300}
#     -> MAE: 832.773
# [158/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 400}
#     -> MAE: 831.930
# [159/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE: 833.156
# [160/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 600}
#     -> MAE: 831.901
# [161/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 200}
#     -> MAE: 833.888
# [162/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 300}
#     -> MAE: 832.147
# [163/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 400}
#     -> MAE: 832.070
# [164/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 500}
#     -> MAE: 833.523
# [165/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 600}
#     -> MAE: 831.523
# [166/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 200}
#     -> MAE: 824.806
# [167/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 300}
#     -> MAE: 828.326
# [168/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 400}
#     -> MAE: 828.453
# [169/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE: 829.386
# [170/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 600}
#     -> MAE: 829.090
# [171/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
#     -> MAE: 832.449
# [172/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 300}
#     -> MAE: 830.460
# [173/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 400}
#     -> MAE: 829.565
# [174/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE: 830.800
# [175/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 600}
#     -> MAE: 830.180
# [176/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 200}
#     -> MAE: 834.043
# [177/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 300}
#     -> MAE: 832.698
# [178/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 400}
#     -> MAE: 832.626
# [179/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 500}
#     -> MAE: 833.834
# [180/300] params: {'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 600}
#     -> MAE: 832.743
# [181/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 200}
#     -> MAE: 845.485
# [182/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 300}
#     -> MAE: 846.541
# [183/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 400}
#     -> MAE: 846.783
# [184/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE: 848.855
# [185/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 600}
#     -> MAE: 848.585
# [186/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200}
#     -> MAE: 840.074
# [187/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 300}
#     -> MAE: 842.860
# [188/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 400}
#     -> MAE: 841.952
# [189/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE: 843.644
# [190/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 600}
#     -> MAE: 842.101
# [191/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 200}
#     -> MAE: 843.103
# [192/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 300}
#     -> MAE: 845.081
# [193/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 400}
#     -> MAE: 846.229
# [194/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 500}
#     -> MAE: 848.389
# [195/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 600}
#     -> MAE: 847.088
# [196/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 200}
#     -> MAE: 848.294
# [197/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 300}
#     -> MAE: 851.051
# [198/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 400}
#     -> MAE: 849.141
# [199/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE: 848.540
# [200/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 600}
#     -> MAE: 848.260
# [201/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
#     -> MAE: 849.706
# [202/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 300}
#     -> MAE: 852.205
# [203/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 400}
#     -> MAE: 850.530
# [204/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE: 851.514
# [205/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 600}
#     -> MAE: 850.701
# [206/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 200}
#     -> MAE: 854.544
# [207/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 300}
#     -> MAE: 860.833
# [208/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 400}
#     -> MAE: 860.019
# [209/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 500}
#     -> MAE: 860.825
# [210/300] params: {'max_depth': 23, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 600}
#     -> MAE: 859.000
# [211/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 200}
#     -> MAE: 838.923
# [212/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 300}
#     -> MAE: 838.837
# [213/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 400}
#     -> MAE: 839.173
# [214/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE: 840.999
# [215/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 600}
#     -> MAE: 839.674
# [216/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200}
#     -> MAE: 833.538
# [217/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 300}
#     -> MAE: 832.088
# [218/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 400}
#     -> MAE: 831.136
# [219/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE: 832.428
# [220/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 600}
#     -> MAE: 832.745
# [221/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 200}
#     -> MAE: 834.772
# [222/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 300}
#     -> MAE: 834.626
# [223/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 400}
#     -> MAE: 833.826
# [224/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 500}
#     -> MAE: 836.142
# [225/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 600}
#     -> MAE: 834.065
# [226/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 200}
#     -> MAE: 828.917
# [227/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 300}
#     -> MAE: 831.991
# [228/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 400}
#     -> MAE: 831.209
# [229/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE: 831.319
# [230/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 600}
#     -> MAE: 830.420
# [231/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
#     -> MAE: 833.144
# [232/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 300}
#     -> MAE: 829.840
# [233/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 400}
#     -> MAE: 828.630
# [234/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE: 828.043
# [235/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 600}
#     -> MAE: 828.689
# [236/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 200}
#     -> MAE: 834.662
# [237/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 300}
#     -> MAE: 831.341
# [238/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 400}
#     -> MAE: 831.248
# [239/300] params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 500}

# %% [markdown]
# Help: hardcode of the result to calculate quicker

# %%
best_params_per_brand_rf = [
    # Brand 0 (MAE=880.558)
    {'max_depth': 17, 'max_features': 0.5,
     'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 200},

    # Brand 1 (MAE=1742.622)
    {'max_depth': 23, 'max_features': 'sqrt',
     'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 200},

    # Brand 2 (MAE=1135.238)
    {'max_depth': 17, 'max_features': 'sqrt',
     'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 600},

    # Brand 3 (MAE=714.560)
    {'max_depth': 15, 'max_features': 0.5,
     'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 600},

    # Brand 4 (MAE=1617.368)
    {'max_depth': 25, 'max_features': 'sqrt',
     'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 600},

    # Brand 5 (MAE=1665.284)
    {'max_depth': 15, 'max_features': 0.5,
     'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 300},

    # Brand 6 (MAE=810.374)
    {'max_depth': 15, 'max_features': 0.5,
     'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 400},

    # Brand 7 (MAE=996.433)
    {'max_depth': 15, 'max_features': 'sqrt',
     'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 300},

    # Brand 8 (MAE=825.807)
    {'max_depth': 15, 'max_features': 'sqrt',
     'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 400},
]

# %% [markdown]
# Then we use the found parameters for the algorithm to predict the prices of our test data. We therefore also log transform the target.

# %%
metrics_per_brand = []
test_pred_list_rf = []
test_pred_list_rf_log = []

for i in range(len(rf_train_x_list)):

    y_train_i = train_y_list[i]
    y_val_i   = val_y_list[i]

    if isinstance(y_train_i, pd.DataFrame):
        y_train_i = y_train_i.iloc[:, 0]
    if isinstance(y_val_i, pd.DataFrame):
        y_val_i = y_val_i.iloc[:, 0]

    # train (log)
    y_train_log = np.log1p(y_train_i)

    model_i = RandomForestRegressor(
        **best_params_per_brand_rf[i],
        random_state=42,
        n_jobs=-1
    )
    model_i.fit(rf_train_x_list[i], y_train_log)

    # val pred (back to original)
    pred_val_log = model_i.predict(rf_val_x_list[i])
    pred_val = np.expm1(pred_val_log)

    mae   = mean_absolute_error(y_val_i, pred_val)
    rmse  = np.sqrt(mean_squared_error(y_val_i, pred_val))
    r2    = r2_score(y_val_i, pred_val)
    medae = median_absolute_error(y_val_i, pred_val)

    metrics_per_brand.append({
        "brand_idx": i,   # oder "brand": brand_names[i]
        "mae": mae,
        "rmse": rmse,
        "r2": r2,
        "medae": medae,
    })

    # final: train+val -> test prediction
    x_trainval_i = pd.concat([rf_train_x_list[i], rf_val_x_list[i]], axis=0)
    y_trainval_i = pd.concat([y_train_i, y_val_i], axis=0)

    model_final = RandomForestRegressor(
        **best_params_per_brand_rf[i],
        random_state=42,
        n_jobs=-1
    )
    model_final.fit(x_trainval_i, np.log1p(y_trainval_i))

    pred_test_log = model_final.predict(rf_test_x_list[i])
    pred_test = np.expm1(pred_test_log)

    test_pred_list_rf.append(pd.Series(pred_test, index=rf_test_x_list[i].index, name="price"))
    test_pred_list_rf_log.append(pd.Series(pred_test_log, index=rf_test_x_list[i].index, name="price_log"))


metrics_rf = pd.DataFrame(metrics_per_brand)

# %% [markdown]
# After that we build the submission.

# %%
# put all brand predictions back together
test_pred_all = pd.concat(test_pred_list_rf).sort_index()

# build submission
submission = test_pred_all.reset_index()
submission.columns = ["CarID", "price"]
submission.to_csv("submission.csv", index=False)

print(submission.head())
print("total preds:", len(submission))

# %% [markdown]
# After that we upload the submission in the submission folder, by the suffix _rf we know which model it was.

# %%
# Save
sub_dir = os.path.join(data_dir, "submissions")
os.makedirs(sub_dir, exist_ok=True)
ts = datetime.now().strftime("%Y%m%d_%H%M")
sub_path = os.path.join(sub_dir, f"30_submission_{ts}_rf.csv")
submission.to_csv(sub_path, index=False)

print(f"Submission saved to: {sub_path}")
display(submission.head(10))

# %% [markdown]
# ## 9.2 Extra Trees Regressor

# %% [markdown]
# For Extra Trees we also use grid search first.

# %%
param_grid_et = {
    "n_estimators": [500, 800, 1200],
    "max_depth": [None, 10, 15, 20],
    "max_features": ["sqrt", 0.5],
    "min_samples_split": [2, 3, 5],
    "min_samples_leaf": [1, 2, 3, 5],
    "bootstrap": [False],
}

grid = list(ParameterGrid(param_grid_et))
n_total = len(grid)

best_params_per_brand_et = []
best_score_per_brand_et = []

for b in range(len(train_x_list)):
    Xtr = train_x_list[b]
    ytr = train_y_list[b]
    Xva = val_x_list[b]
    yva = val_y_list[b]

    # falls y DataFrame -> Series
    if isinstance(ytr, pd.DataFrame): ytr = ytr.iloc[:, 0]
    if isinstance(yva, pd.DataFrame): yva = yva.iloc[:, 0]

    best_mae = float("inf")
    best_params = None

    print("\n==============================")
    print(f"Brand {b}: ExtraTrees grid search over {n_total} configs")

    for i, params in enumerate(grid, start=1):
        print(f"[{i}/{n_total}] params: {params}")

        model = ExtraTreesRegressor(**params, random_state=42, n_jobs=-1)

        # ---- log1p training ----
        model.fit(Xtr, np.log1p(ytr))

        # ---- predict + inverse ----
        pred_log = model.predict(Xva)
        pred = np.expm1(pred_log)

        mae = mean_absolute_error(yva, pred)
        print(f"    -> MAE (log1p): {mae:.3f}")

        if mae < best_mae:
            best_mae = mae
            best_params = params
            print(f"    NEW BEST: MAE={best_mae:.3f} | params={best_params}")

    best_params_per_brand_et.append(best_params)
    best_score_per_brand_et.append(best_mae)

print("\n===== FINAL BEST EXTRA-TREES PER BRAND =====")
for b, (p, s) in enumerate(zip(best_params_per_brand_et, best_score_per_brand_et)):
    print(f"Brand {b}: MAE={s:.3f} | params={p}")
# Out:
#     -> MAE (log1p): 1521.368
# [174/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 1200}
#     -> MAE (log1p): 1523.082
# [175/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE (log1p): 1526.188
# [176/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 800}
#     -> MAE (log1p): 1521.368
# [177/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 1200}
#     -> MAE (log1p): 1523.082
# [178/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE (log1p): 1526.188
# [179/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 800}
#     -> MAE (log1p): 1521.368
# [180/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 1200}
#     -> MAE (log1p): 1523.082
# [181/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 500}
#     -> MAE (log1p): 1157.574
# [182/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 800}
#     -> MAE (log1p): 1159.163
# [183/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 1200}
#     -> MAE (log1p): 1158.485
# [184/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE (log1p): 1158.352
# [185/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 800}
#     -> MAE (log1p): 1158.200
# [186/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 1200}
#     -> MAE (log1p): 1159.550
# [187/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE (log1p): 1160.324
# [188/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 800}
#     -> MAE (log1p): 1159.075
# [189/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 1200}
#     -> MAE (log1p): 1159.590
# [190/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 500}
#     -> MAE (log1p): 1163.353
# [191/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 800}
#     -> MAE (log1p): 1162.004
# [192/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 1200}
#     -> MAE (log1p): 1163.617
# [193/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE (log1p): 1163.353
# [194/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 800}
#     -> MAE (log1p): 1162.004
# [195/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 1200}
#     -> MAE (log1p): 1163.617
# [196/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE (log1p): 1164.003
# [197/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 800}
#     -> MAE (log1p): 1164.952
# [198/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 1200}
#     -> MAE (log1p): 1165.072
# [199/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 500}
#     -> MAE (log1p): 1187.422
# [200/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 800}
#     -> MAE (log1p): 1186.610
# [201/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 1200}
#     -> MAE (log1p): 1185.453
# [202/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE (log1p): 1187.422
# [203/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 800}
#     -> MAE (log1p): 1186.610
# [204/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 1200}
#     -> MAE (log1p): 1185.453
# [205/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE (log1p): 1187.422
# [206/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 800}
#     -> MAE (log1p): 1186.610
# [207/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 1200}
#     -> MAE (log1p): 1185.453
# [208/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 500}
#     -> MAE (log1p): 1227.030
# [209/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 800}
#     -> MAE (log1p): 1226.788
# [210/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 1200}
#     -> MAE (log1p): 1225.453
# [211/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE (log1p): 1227.030
# [212/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 800}
#     -> MAE (log1p): 1226.788
# [213/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 1200}
#     -> MAE (log1p): 1225.453
# [214/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE (log1p): 1227.030
# [215/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 800}
#     -> MAE (log1p): 1226.788
# [216/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 1200}
#     -> MAE (log1p): 1225.453
# [217/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 500}
#     -> MAE (log1p): 1167.535
# [218/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 800}
#     -> MAE (log1p): 1165.131
# [219/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 1200}
#     -> MAE (log1p): 1165.438
# [220/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE (log1p): 1160.884
# [221/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 800}
#     -> MAE (log1p): 1161.480
# [222/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 1200}
#     -> MAE (log1p): 1161.066
# [223/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE (log1p): 1165.776
# [224/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 800}
#     -> MAE (log1p): 1166.369
# [225/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 1200}
#     -> MAE (log1p): 1166.972
# [226/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 500}
#     -> MAE (log1p): 1264.390
# [227/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 800}
#     -> MAE (log1p): 1263.801
# [228/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 1200}
#     -> MAE (log1p): 1263.379
# [229/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE (log1p): 1264.390
# [230/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 800}
#     -> MAE (log1p): 1263.801
# [231/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 1200}
#     -> MAE (log1p): 1263.379
# [232/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE (log1p): 1270.909
# [233/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 800}
#     -> MAE (log1p): 1270.585
# [234/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 1200}
#     -> MAE (log1p): 1270.053
# [235/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 500}
#     -> MAE (log1p): 1364.005
# [236/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 800}
#     -> MAE (log1p): 1361.714
# [237/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 1200}
#     -> MAE (log1p): 1360.965
# [238/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE (log1p): 1364.005
# [239/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 800}
#     -> MAE (log1p): 1361.714
# [240/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 1200}
#     -> MAE (log1p): 1360.965
# [241/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE (log1p): 1364.005
# [242/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 800}
#     -> MAE (log1p): 1361.714
# [243/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 1200}
#     -> MAE (log1p): 1360.965
# [244/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 500}
#     -> MAE (log1p): 1484.170
# [245/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 800}
#     -> MAE (log1p): 1481.547
# [246/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 1200}
#     -> MAE (log1p): 1481.537
# [247/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE (log1p): 1484.170
# [248/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 800}
#     -> MAE (log1p): 1481.547
# [249/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 1200}
#     -> MAE (log1p): 1481.537
# [250/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE (log1p): 1484.170
# [251/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 800}
#     -> MAE (log1p): 1481.547
# [252/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 1200}
#     -> MAE (log1p): 1481.537
# [253/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 500}
#     -> MAE (log1p): 1189.662
# [254/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 800}
#     -> MAE (log1p): 1189.559
# [255/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 1200}
#     -> MAE (log1p): 1188.913
# [256/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE (log1p): 1170.730
# [257/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 800}
#     -> MAE (log1p): 1170.103
# [258/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 1200}
#     -> MAE (log1p): 1170.945
# [259/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE (log1p): 1159.250
# [260/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 800}
#     -> MAE (log1p): 1158.641
# [261/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 1200}
#     -> MAE (log1p): 1158.262
# [262/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 500}
#     -> MAE (log1p): 1153.772
#     NEW BEST: MAE=1153.772 | params={'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 500}
# [263/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 800}
#     -> MAE (log1p): 1153.973
# [264/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 1200}
#     -> MAE (log1p): 1153.142
#     NEW BEST: MAE=1153.142 | params={'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 1200}
# [265/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE (log1p): 1153.772
# [266/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 800}
#     -> MAE (log1p): 1153.973
# [267/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 1200}
#     -> MAE (log1p): 1153.142
# [268/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE (log1p): 1155.660
# [269/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 800}
#     -> MAE (log1p): 1154.862
# [270/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 1200}
#     -> MAE (log1p): 1155.681
# [271/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 500}
#     -> MAE (log1p): 1175.499
# [272/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 800}
#     -> MAE (log1p): 1175.974
# [273/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 1200}
#     -> MAE (log1p): 1175.414
# [274/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE (log1p): 1175.499
# [275/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 800}
#     -> MAE (log1p): 1175.974
# [276/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 1200}
#     -> MAE (log1p): 1175.414
# [277/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE (log1p): 1175.499
# [278/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 800}
#     -> MAE (log1p): 1175.974
# [279/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 1200}
#     -> MAE (log1p): 1175.414
# [280/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 500}
#     -> MAE (log1p): 1218.267
# [281/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 800}
#     -> MAE (log1p): 1216.891
# [282/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 1200}
#     -> MAE (log1p): 1218.308
# [283/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE (log1p): 1218.267
# [284/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 800}
#     -> MAE (log1p): 1216.891
# [285/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 1200}
#     -> MAE (log1p): 1218.308
# [286/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE (log1p): 1218.267
# [287/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 800}
#     -> MAE (log1p): 1216.891
# [288/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 1200}
#     -> MAE (log1p): 1218.308
#
# ==============================
# Brand 3: ExtraTrees grid search over 288 configs
# [1/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 500}
#     -> MAE (log1p): 837.866
#     NEW BEST: MAE=837.866 | params={'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 500}
# [2/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 800}
#     -> MAE (log1p): 838.227
# [3/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 1200}
#     -> MAE (log1p): 838.084
# [4/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE (log1p): 806.967
#     NEW BEST: MAE=806.967 | params={'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 500}
# [5/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 800}
#     -> MAE (log1p): 806.843
#     NEW BEST: MAE=806.843 | params={'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 800}
# [6/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 1200}
#     -> MAE (log1p): 806.424
#     NEW BEST: MAE=806.424 | params={'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 1200}
# [7/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE (log1p): 774.031
#     NEW BEST: MAE=774.031 | params={'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 500}
# [8/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 800}
#     -> MAE (log1p): 773.157
#     NEW BEST: MAE=773.157 | params={'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 800}
# [9/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 1200}
#     -> MAE (log1p): 772.854
#     NEW BEST: MAE=772.854 | params={'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 1200}
# [10/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 500}
#     -> MAE (log1p): 775.487
# [11/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 800}
#     -> MAE (log1p): 773.459
# [12/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 1200}
#     -> MAE (log1p): 773.601
# [13/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE (log1p): 775.487
# [14/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 800}
#     -> MAE (log1p): 773.459
# [15/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 1200}
#     -> MAE (log1p): 773.601
# [16/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE (log1p): 773.929
# [17/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 800}
#     -> MAE (log1p): 773.794
# [18/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 1200}
#     -> MAE (log1p): 774.201
# [19/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 500}
#     -> MAE (log1p): 802.481
# [20/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 800}
#     -> MAE (log1p): 802.608
# [21/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 1200}
#     -> MAE (log1p): 803.497
# [22/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE (log1p): 802.481
# [23/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 800}
#     -> MAE (log1p): 802.608
# [24/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 1200}
#     -> MAE (log1p): 803.497
# [25/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE (log1p): 802.481
# [26/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 800}
#     -> MAE (log1p): 802.608
# [27/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 1200}
#     -> MAE (log1p): 803.497
# [28/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 500}
#     -> MAE (log1p): 839.468
# [29/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 800}
#     -> MAE (log1p): 840.360
# [30/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 1200}
#     -> MAE (log1p): 840.881
# [31/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE (log1p): 839.468
# [32/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 800}
#     -> MAE (log1p): 840.360
# [33/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 1200}
#     -> MAE (log1p): 840.881
# [34/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE (log1p): 839.468
# [35/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 800}
#     -> MAE (log1p): 840.360
# [36/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 1200}
#     -> MAE (log1p): 840.881
# [37/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 500}
#     -> MAE (log1p): 837.442
# [38/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 800}
#     -> MAE (log1p): 837.590
# [39/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 1200}
#     -> MAE (log1p): 837.825
# [40/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE (log1p): 805.271
# [41/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 800}
#     -> MAE (log1p): 805.685
# [42/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 1200}
#     -> MAE (log1p): 805.171
# [43/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE (log1p): 774.801
# [44/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 800}
#     -> MAE (log1p): 774.703
# [45/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 1200}
#     -> MAE (log1p): 774.284
# [46/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 500}
#     -> MAE (log1p): 748.728
#     NEW BEST: MAE=748.728 | params={'bootstrap': False, 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 500}
# [47/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 800}
#     -> MAE (log1p): 749.277
# [48/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 1200}
#     -> MAE (log1p): 749.167
# [49/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE (log1p): 748.728
# [50/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 800}
#     -> MAE (log1p): 749.277
# [51/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 1200}
#     -> MAE (log1p): 749.167
# [52/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE (log1p): 749.756
# [53/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 800}
#     -> MAE (log1p): 749.718
# [54/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 1200}
#     -> MAE (log1p): 749.958
# [55/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 500}
#     -> MAE (log1p): 752.088
# [56/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 800}
#     -> MAE (log1p): 752.395
# [57/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 1200}
#     -> MAE (log1p): 752.368
# [58/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE (log1p): 752.088
# [59/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 800}
#     -> MAE (log1p): 752.395
# [60/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 1200}
#     -> MAE (log1p): 752.368
# [61/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE (log1p): 752.088
# [62/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 800}
#     -> MAE (log1p): 752.395
# [63/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 1200}
#     -> MAE (log1p): 752.368
# [64/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 500}
#     -> MAE (log1p): 763.832
# [65/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 800}
#     -> MAE (log1p): 764.023
# [66/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 1200}
#     -> MAE (log1p): 764.806
# [67/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE (log1p): 763.832
# [68/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 800}
#     -> MAE (log1p): 764.023
# [69/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 1200}
#     -> MAE (log1p): 764.806
# [70/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE (log1p): 763.832
# [71/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 800}
#     -> MAE (log1p): 764.023
# [72/288] params: {'bootstrap': False, 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 1200}
#     -> MAE (log1p): 764.806
# [73/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 500}
#     -> MAE (log1p): 929.954
# [74/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 800}
#     -> MAE (log1p): 931.538
# [75/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 1200}
#     -> MAE (log1p): 932.168
# [76/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE (log1p): 922.072
# [77/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 800}
#     -> MAE (log1p): 926.770
# [78/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 1200}
#     -> MAE (log1p): 928.751
# [79/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE (log1p): 929.217
# [80/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 800}
#     -> MAE (log1p): 929.033
# [81/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 1200}
#     -> MAE (log1p): 929.745
# [82/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 500}
#     -> MAE (log1p): 935.511
# [83/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 800}
#     -> MAE (log1p): 936.218
# [84/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 1200}
#     -> MAE (log1p): 936.671
# [85/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE (log1p): 935.511
# [86/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 800}
#     -> MAE (log1p): 936.218
# [87/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 1200}
#     -> MAE (log1p): 936.671
# [88/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE (log1p): 939.537
# [89/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 800}
#     -> MAE (log1p): 939.867
# [90/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 1200}
#     -> MAE (log1p): 941.968
# [91/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 500}
#     -> MAE (log1p): 946.596
# [92/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 800}
#     -> MAE (log1p): 951.606
# [93/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 1200}
#     -> MAE (log1p): 950.936
# [94/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE (log1p): 946.596
# [95/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 800}
#     -> MAE (log1p): 951.606
# [96/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 1200}
#     -> MAE (log1p): 950.936
# [97/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE (log1p): 946.596
# [98/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 800}
#     -> MAE (log1p): 951.606
# [99/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 1200}
#     -> MAE (log1p): 950.936
# [100/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 500}
#     -> MAE (log1p): 959.500
# [101/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 800}
#     -> MAE (log1p): 965.666
# [102/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 1200}
#     -> MAE (log1p): 965.944
# [103/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE (log1p): 959.500
# [104/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 800}
#     -> MAE (log1p): 965.666
# [105/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 1200}
#     -> MAE (log1p): 965.944
# [106/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE (log1p): 959.500
# [107/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 800}
#     -> MAE (log1p): 965.666
# [108/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 1200}
#     -> MAE (log1p): 965.944
# [109/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 500}
#     -> MAE (log1p): 806.467
# [110/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 800}
#     -> MAE (log1p): 806.752
# [111/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 1200}
#     -> MAE (log1p): 807.747
# [112/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE (log1p): 807.643
# [113/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 800}
#     -> MAE (log1p): 807.307
# [114/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 1200}
#     -> MAE (log1p): 808.129
# [115/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE (log1p): 809.086
# [116/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 800}
#     -> MAE (log1p): 808.180
# [117/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 1200}
#     -> MAE (log1p): 808.178
# [118/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 500}
#     -> MAE (log1p): 809.502
# [119/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 800}
#     -> MAE (log1p): 809.063
# [120/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 1200}
#     -> MAE (log1p): 809.494
# [121/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE (log1p): 809.502
# [122/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 800}
#     -> MAE (log1p): 809.063
# [123/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 1200}
#     -> MAE (log1p): 809.494
# [124/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE (log1p): 806.926
# [125/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 800}
#     -> MAE (log1p): 807.834
# [126/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 1200}
#     -> MAE (log1p): 809.443
# [127/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 500}
#     -> MAE (log1p): 811.239
# [128/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 800}
#     -> MAE (log1p): 811.033
# [129/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 1200}
#     -> MAE (log1p): 810.809
# [130/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE (log1p): 811.239
# [131/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 800}
#     -> MAE (log1p): 811.033
# [132/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 1200}
#     -> MAE (log1p): 810.809
# [133/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE (log1p): 811.239
# [134/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 800}
#     -> MAE (log1p): 811.033
# [135/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 1200}
#     -> MAE (log1p): 810.809
# [136/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 500}
#     -> MAE (log1p): 816.675
# [137/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 800}
#     -> MAE (log1p): 816.869
# [138/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 1200}
#     -> MAE (log1p): 817.546
# [139/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE (log1p): 816.675
# [140/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 800}
#     -> MAE (log1p): 816.869
# [141/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 1200}
#     -> MAE (log1p): 817.546
# [142/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE (log1p): 816.675
# [143/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 800}
#     -> MAE (log1p): 816.869
# [144/288] params: {'bootstrap': False, 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 1200}
#     -> MAE (log1p): 817.546
# [145/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 500}
#     -> MAE (log1p): 771.370
# [146/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 800}
#     -> MAE (log1p): 771.868
# [147/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 1200}
#     -> MAE (log1p): 771.586
# [148/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE (log1p): 771.005
# ...
# [206/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 800}
#     -> MAE (log1p): 905.258
# [207/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 1200}
#     -> MAE (log1p): 903.234
# [208/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 500}
#     -> MAE (log1p): 940.001
# [209/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 800}
#     -> MAE (log1p): 939.471
# [210/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 1200}
#     -> MAE (log1p): 937.819
# [211/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE (log1p): 940.001
# [212/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 800}
#     -> MAE (log1p): 939.471
# [213/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 1200}
#     -> MAE (log1p): 937.819
# [214/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE (log1p): 940.001
# [215/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 800}
#     -> MAE (log1p): 939.471
# [216/288] params: {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 1200}
#     -> MAE (log1p): 937.819
# [217/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 500}
#     -> MAE (log1p): 900.519
# [218/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 800}
#     -> MAE (log1p): 898.618
# [219/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 1200}
#     -> MAE (log1p): 898.142
# [220/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE (log1p): 876.726
# [221/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 800}
#     -> MAE (log1p): 874.893
# [222/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 1200}
#     -> MAE (log1p): 874.890
# [223/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE (log1p): 853.392
# [224/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 800}
#     -> MAE (log1p): 852.530
# [225/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 1200}
#     -> MAE (log1p): 851.917
# [226/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 500}
#     -> MAE (log1p): 921.842
# [227/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 800}
#     -> MAE (log1p): 922.920
# [228/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 1200}
#     -> MAE (log1p): 922.214
# [229/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE (log1p): 921.842
# [230/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 800}
#     -> MAE (log1p): 922.920
# [231/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 1200}
#     -> MAE (log1p): 922.214
# [232/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE (log1p): 927.797
# [233/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 800}
#     -> MAE (log1p): 923.890
# [234/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 1200}
#     -> MAE (log1p): 923.135
# [235/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 500}
#     -> MAE (log1p): 987.237
# [236/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 800}
#     -> MAE (log1p): 984.138
# [237/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 1200}
#     -> MAE (log1p): 985.296
# [238/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE (log1p): 987.237
# [239/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 800}
#     -> MAE (log1p): 984.138
# [240/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 1200}
#     -> MAE (log1p): 985.296
# [241/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE (log1p): 987.237
# [242/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 800}
#     -> MAE (log1p): 984.138
# [243/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 1200}
#     -> MAE (log1p): 985.296
# [244/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 500}
#     -> MAE (log1p): 1063.067
# [245/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 800}
#     -> MAE (log1p): 1064.784
# [246/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 1200}
#     -> MAE (log1p): 1061.505
# [247/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE (log1p): 1063.067
# [248/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 800}
#     -> MAE (log1p): 1064.784
# [249/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 1200}
#     -> MAE (log1p): 1061.505
# [250/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE (log1p): 1063.067
# [251/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 800}
#     -> MAE (log1p): 1064.784
# [252/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 1200}
#     -> MAE (log1p): 1061.505
# [253/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 500}
#     -> MAE (log1p): 925.421
# [254/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 800}
#     -> MAE (log1p): 923.175
# [255/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 1200}
#     -> MAE (log1p): 923.652
# [256/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE (log1p): 896.817
# [257/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 800}
#     -> MAE (log1p): 895.216
# [258/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 1200}
#     -> MAE (log1p): 894.242
# [259/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE (log1p): 869.894
# [260/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 800}
#     -> MAE (log1p): 871.029
# [261/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 1200}
#     -> MAE (log1p): 870.600
# [262/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 500}
#     -> MAE (log1p): 881.493
# [263/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 800}
#     -> MAE (log1p): 882.329
# [264/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 1200}
#     -> MAE (log1p): 880.703
# [265/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE (log1p): 881.493
# [266/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 800}
#     -> MAE (log1p): 882.329
# [267/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 1200}
#     -> MAE (log1p): 880.703
# [268/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE (log1p): 877.799
# [269/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 800}
#     -> MAE (log1p): 877.453
# [270/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 1200}
#     -> MAE (log1p): 878.110
# [271/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 500}
#     -> MAE (log1p): 901.168
# [272/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 800}
#     -> MAE (log1p): 901.102
# [273/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 1200}
#     -> MAE (log1p): 901.517
# [274/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE (log1p): 901.168
# [275/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 800}
#     -> MAE (log1p): 901.102
# [276/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 1200}
#     -> MAE (log1p): 901.517
# [277/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE (log1p): 901.168
# [278/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 800}
#     -> MAE (log1p): 901.102
# [279/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 1200}
#     -> MAE (log1p): 901.517
# [280/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 500}
#     -> MAE (log1p): 938.672
# [281/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 800}
#     -> MAE (log1p): 937.911
# [282/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 1200}
#     -> MAE (log1p): 937.635
# [283/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 500}
#     -> MAE (log1p): 938.672
# [284/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 800}
#     -> MAE (log1p): 937.911
# [285/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 1200}
#     -> MAE (log1p): 937.635
# [286/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 500}
#     -> MAE (log1p): 938.672
# [287/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 800}
#     -> MAE (log1p): 937.911
# [288/288] params: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 1200}
#     -> MAE (log1p): 937.635
#
# ===== FINAL BEST EXTRA-TREES PER BRAND =====
# Brand 0: MAE=915.827 | params={'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 800}
# Brand 1: MAE=1698.928 | params={'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 500}
# Brand 2: MAE=1153.142 | params={'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 1200}
# Brand 3: MAE=745.223 | params={'bootstrap': False, 'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 500}
# Brand 4: MAE=1461.347 | params={'bootstrap': False, 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 1200}
# Brand 5: MAE=1674.251 | params={'bootstrap': False, 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 500}
# Brand 6: MAE=791.083 | params={'bootstrap': False, 'max_depth': 15, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 800}
# Brand 7: MAE=1042.743 | params={'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 500}
# Brand 8: MAE=851.841 | params={'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 500}

# %% [markdown]
# Help: hardcode of the result to calculate quicker

# %%
best_params_per_brand_et = [
    # Brand 0 (MAE=876.688)
    {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5,
     'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 800},

    # Brand 1 (MAE=1715.926)
    {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5,
     'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 500},

    # Brand 2 (MAE=1122.832)
    {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5,
     'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 1200},

    # Brand 3 (MAE=727.604)
    {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5,
     'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 1200},

    # Brand 4 (MAE=1574.483)
    {'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt',
     'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 1200},

    # Brand 5 (MAE=1658.852)
    {'bootstrap': False, 'max_depth': 20, 'max_features': 0.5,
     'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 500},

    # Brand 6 (MAE=811.462)
    {'bootstrap': False, 'max_depth': None, 'max_features': 0.5,
     'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 500},

    # Brand 7 (MAE=1018.251)
    {'bootstrap': False, 'max_depth': 15, 'max_features': 0.5,
     'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 500},

    # Brand 8 (MAE=791.526)
    {'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt',
     'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 800},
]

# %% [markdown]
# Then we use the found parameters for the algorithm to predict the prices of our test data. We therefore also log transform the target.

# %%
test_pred_list_et = []
test_pred_list_et_log = []
metrics_per_brand_et = []

val_pred_list_et_log = []

for i in range(len(train_x_list)):
    X_tr, X_va, X_te = train_x_list[i], val_x_list[i], test_x_list[i]
    y_tr, y_va = train_y_list[i], val_y_list[i]
    if isinstance(y_tr, pd.DataFrame): y_tr = y_tr.iloc[:,0]
    if isinstance(y_va, pd.DataFrame): y_va = y_va.iloc[:,0]

    params_et = best_params_per_brand_et[i].copy()
    params_et['criterion'] = 'absolute_error'

    # train -> val preds
    et_val = ExtraTreesRegressor(**params_et, random_state=42, n_jobs=-1)
    et_val.fit(X_tr, np.log1p(y_tr))

    pred_va_log = et_val.predict(X_va)
    pred_va = np.expm1(pred_va_log)

    val_pred_list_et_log.append(pd.Series(pred_va_log, index=X_va.index, name="price_log"))

    # metrics
    mae   = mean_absolute_error(y_va, pred_va)
    rmse  = np.sqrt(mean_squared_error(y_va, pred_va))
    r2    = r2_score(y_va, pred_va)
    medae = median_absolute_error(y_va, pred_va)

    metrics_per_brand_et.append({"brand_idx": i, "mae": mae, "rmse": rmse, "r2": r2, "medae": medae})

    # final: train+val -> test
    x_trainval = pd.concat([X_tr, X_va], axis=0)
    y_trainval = pd.concat([y_tr, y_va], axis=0)

    et_final = ExtraTreesRegressor(**params_et, random_state=42, n_jobs=-1)
    et_final.fit(x_trainval, np.log1p(y_trainval))

    pred_log_te = et_final.predict(X_te)
    pred_te = np.expm1(pred_log_te)

    test_pred_list_et.append(pd.Series(pred_te, index=X_te.index, name="price"))
    test_pred_list_et_log.append(pd.Series(pred_log_te, index=X_te.index, name="price_log"))
metrics_et = pd.DataFrame(metrics_per_brand_et)

# %% [markdown]
# After that we build the submission.

# %%
# put all brand predictions back together
test_pred_all = pd.concat(test_pred_list_et).sort_index()

# build submission
submission = test_pred_all.reset_index()
submission.columns = ["CarID", "price"]
submission.to_csv("submission.csv", index=False)

print(submission.head())
print("total preds:", len(submission))
# Out:
#    CarID         price
# 0  75973   9720.215973
# 1  75974  21445.120999
# 2  75975  29859.575596
# 3  75976  26772.791890
# 4  75977  14617.863613
# total preds: 32567

# %% [markdown]
# After that we upload the submission in the submission folder, by the suffix _etr we know which model it was.

# %%
# Save
sub_dir = os.path.join(data_dir, "submissions")
os.makedirs(sub_dir, exist_ok=True)
ts = datetime.now().strftime("%Y%m%d_%H%M")
sub_path = os.path.join(sub_dir, f"30_submission_{ts}_etr.csv")
submission.to_csv(sub_path, index=False)

print(f"Submission saved to: {sub_path}")
display(submission.head(10))
# Out:
# Submission saved to: ../data/submissions\30_submission_20251215_1920_etr.csv
#    CarID         price
# 0  75973   9720.215973
# 1  75974  21445.120999
# 2  75975  29859.575596
# 3  75976  26772.791890
# 4  75977  14617.863613
# 5  75978  22570.464958
# 6  75979  33589.706667
# 7  75980  26172.603106
# 8  75981  16090.246835
# 9  75982  24814.623516

# %% [markdown]
# ## 9.3 Hist Gradient Boosting Regressor

# %%
# ---- kleines, "high impact" Grid für HGB ----
param_grid_hgb = {
    "max_depth": [6, 8],
    "learning_rate": [0.03, 0.06, 0.1],
    "min_samples_leaf": [10, 30, 50],
    "l2_regularization": [0.02, 0.05, 0.1],
    "max_bins": [128, 255],
    "max_iter": [4000],
    "early_stopping": [True],
}

grid = list(ParameterGrid(param_grid_hgb))
n_total = len(grid)

best_params_per_brand_hgb = []
best_score_per_brand_hgb  = []

for b in range(len(train_x_list)):
    Xtr = train_x_list[b]
    ytr = train_y_list[b]
    Xva = val_x_list[b]
    yva = val_y_list[b]

    # falls y DataFrame -> Series
    if isinstance(ytr, pd.DataFrame): ytr = ytr.iloc[:, 0]
    if isinstance(yva, pd.DataFrame): yva = yva.iloc[:, 0]

    best_mae = float("inf")
    best_params = None

    print("\n==============================")
    print(f"Brand {b}: HGB grid search over {n_total} configs")

    for i, params in enumerate(grid, start=1):
        print(f"[{i}/{n_total}] params: {params}")

        model = HistGradientBoostingRegressor(
            **params,
            random_state=42
        )

        # ---- log1p training ----
        model.fit(Xtr, np.log1p(ytr))

        # ---- predict + inverse ----
        pred_log = model.predict(Xva)
        pred = np.expm1(pred_log)

        mae = mean_absolute_error(yva, pred)
        print(f"    -> MAE (log1p): {mae:.3f}")

        if mae < best_mae:
            best_mae = mae
            best_params = params
            print(f"    NEW BEST: MAE={best_mae:.3f} | params={best_params}")

    best_params_per_brand_hgb.append(best_params)
    best_score_per_brand_hgb.append(best_mae)

print("\n===== FINAL BEST HGB PER BRAND =====")
for b, (p, s) in enumerate(zip(best_params_per_brand_hgb, best_score_per_brand_hgb)):
    print(f"Brand {b}: MAE={s:.3f} | params={p}")
# Out:
# ==============================
# Brand 0: HGB grid search over 108 configs
# [1/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
# C:\Users\gmbtd\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "C:\Users\gmbtd\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#         "wmic CPU Get NumberOfCores /Format:csv".split(),
#         capture_output=True,
#         text=True,
#     )
#   File "C:\Users\gmbtd\anaconda3\Lib\subprocess.py", line 554, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\gmbtd\anaconda3\Lib\subprocess.py", line 1039, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#     ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                         pass_fds, cwd, env,
#                         ^^^^^^^^^^^^^^^^^^^
#     ...<5 lines>...
#                         gid, gids, uid, umask,
#                         ^^^^^^^^^^^^^^^^^^^^^^
#                         start_new_session, process_group)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\gmbtd\anaconda3\Lib\subprocess.py", line 1554, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#                              # no special security
#                              ^^^^^^^^^^^^^^^^^^^^^
#     ...<4 lines>...
#                              cwd,
#                              ^^^^
#                              startupinfo)
#                              ^^^^^^^^^^^^
#     -> MAE (log1p): 908.095
#     NEW BEST: MAE=908.095 | params={'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
# [2/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 924.155
# [3/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 935.819
# [4/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 913.066
# [5/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 922.150
# [6/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 928.711
# [7/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 915.691
# [8/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 921.612
# [9/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 927.236
# [10/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 918.470
# [11/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 915.995
# [12/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 919.247
# [13/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 913.959
# [14/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 925.902
# [15/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 926.126
# [16/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 906.985
#     NEW BEST: MAE=906.985 | params={'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
# [17/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 915.411
# [18/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 922.898
# [19/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.06, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 913.851
# [20/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.06, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 915.701
# [21/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.06, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 921.832
# [22/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.06, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 916.650
# [23/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.06, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 914.621
# [24/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.06, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 922.615
# [25/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 910.436
# [26/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 914.605
# [27/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 934.982
# [28/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 915.626
# [29/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 914.225
# [30/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 924.941
# [31/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.1, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 913.767
# [32/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.1, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 912.851
# [33/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.1, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 923.867
# [34/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.1, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 912.801
# [35/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.1, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 919.473
# [36/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.1, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 924.677
# [37/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 916.701
# [38/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 933.159
# [39/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 929.552
# [40/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 911.666
# [41/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 918.661
# [42/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 923.984
# [43/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 914.032
# [44/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 913.527
# [45/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 929.419
# [46/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 916.957
# [47/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 915.045
# [48/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 919.857
# [49/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 919.310
# [50/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 913.762
# [51/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 930.796
# [52/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 914.336
# [53/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 918.652
# [54/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 923.673
# [55/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.06, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 909.704
# [56/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.06, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 913.979
# [57/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.06, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 925.885
# [58/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.06, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 911.895
# [59/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.06, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 919.391
# [60/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.06, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 922.939
# [61/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 912.407
# [62/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 927.260
# [63/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 927.584
# [64/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 907.602
# [65/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 913.680
# [66/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 920.993
# [67/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.1, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 919.649
# [68/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.1, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 917.984
# [69/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.1, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 922.093
# [70/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.1, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 910.776
# [71/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.1, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 912.383
# [72/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.1, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 924.801
# [73/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 910.632
# [74/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 923.040
# [75/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 933.921
# [76/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 911.220
# [77/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 913.420
# [78/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 927.008
# [79/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 912.913
# [80/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 919.132
# [81/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 923.624
# [82/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 923.422
# [83/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 916.628
# [84/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 926.198
# [85/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 909.684
# [86/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 918.156
# [87/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 927.836
# [88/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 908.112
# [89/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 911.311
# [90/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 922.062
# [91/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.06, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 912.919
# [92/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.06, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 925.920
# [93/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.06, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 928.053
# [94/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.06, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 909.090
# [95/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.06, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 911.488
# [96/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.06, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 922.994
# [97/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 917.255
# [98/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 918.735
# [99/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 929.058
# [100/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 907.750
# [101/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 915.754
# [102/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 917.381
# [103/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.1, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 915.075
# [104/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.1, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 912.467
# [105/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.1, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 925.458
# [106/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.1, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 912.248
# [107/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.1, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 916.695
# [108/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.1, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 924.783
#
# ==============================
# Brand 1: HGB grid search over 108 configs
# [1/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 1837.462
#     NEW BEST: MAE=1837.462 | params={'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
# [2/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 1928.604
# [3/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 1979.448
# [4/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 1828.058
#     NEW BEST: MAE=1828.058 | params={'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
# [5/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 1848.309
# [6/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 1951.788
# [7/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 1834.857
# [8/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 1866.313
# [9/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 1959.707
# [10/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 1796.311
#     NEW BEST: MAE=1796.311 | params={'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
# [11/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 1859.139
# [12/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 1895.794
# [13/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 1831.926
# [14/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 1882.387
# [15/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 1938.358
# [16/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 1830.903
# [17/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 1815.712
# [18/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 1875.868
# [19/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.06, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 1835.994
# [20/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.06, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 1845.435
# [21/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.06, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 1912.809
# [22/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.06, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 1802.693
# [23/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.06, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 1873.750
# [24/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.06, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 1890.791
# [25/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 1815.240
# [26/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 1855.289
# [27/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 1930.363
# [28/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 1802.539
# [29/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 1844.674
# [30/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 1850.771
# [31/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.1, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 1789.234
#     NEW BEST: MAE=1789.234 | params={'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.1, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
# [32/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.1, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 1868.660
# [33/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.1, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 1883.307
# [34/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.1, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 1819.843
# [35/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.1, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 1802.967
# [36/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.1, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 1903.355
# [37/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 1812.111
# [38/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 1939.918
# [39/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 1971.889
# [40/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 1780.285
#     NEW BEST: MAE=1780.285 | params={'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
# [41/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 1846.690
# [42/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 1911.818
# [43/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 1861.573
# [44/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 1879.535
# [45/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 1951.113
# [46/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 1783.918
# [47/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 1831.934
# [48/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 1945.180
# [49/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 1827.637
# [50/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 1905.821
# [51/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 1921.611
# [52/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 1784.020
# [53/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 1798.165
# [54/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 1912.122
# [55/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.06, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 1828.463
# [56/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.06, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 1840.726
# [57/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.06, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 1910.441
# [58/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.06, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 1798.430
# [59/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.06, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 1802.467
# [60/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.06, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 1887.629
# [61/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 1824.632
# [62/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 1804.719
# [63/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 1937.090
# [64/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 1795.766
# [65/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 1801.535
# [66/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 1944.823
# [67/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.1, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 1791.204
# [68/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.1, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 1830.973
# [69/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.1, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 1968.390
# [70/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.1, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 1816.897
# [71/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.1, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 1881.760
# [72/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.1, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 1902.708
# [73/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 1845.179
# [74/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 1968.997
# [75/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 1970.263
# [76/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 1792.704
# [77/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 1862.384
# [78/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 1913.816
# [79/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 1887.267
# [80/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 1883.467
# [81/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 1955.474
# [82/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 1774.763
#     NEW BEST: MAE=1774.763 | params={'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
# [83/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 1873.997
# [84/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 1914.703
# [85/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 1807.845
# [86/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 1891.493
# [87/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 1967.373
# [88/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 1766.397
#     NEW BEST: MAE=1766.397 | params={'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
# [89/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 1878.175
# [90/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 1882.031
# [91/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.06, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 1833.757
# [92/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.06, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 1898.604
# [93/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.06, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 1948.338
# [94/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.06, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 1782.898
# [95/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.06, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 1852.784
# [96/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.06, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 1905.203
# [97/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 1807.783
# [98/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 1884.365
# [99/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 1925.049
# [100/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 1781.714
# [101/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 1820.590
# [102/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 1946.470
# [103/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.1, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 1793.792
# [104/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.1, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 1833.097
# [105/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.1, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 1901.675
# [106/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.1, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 1766.857
# [107/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.1, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 1840.359
# [108/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.1, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 1891.143
#
# ==============================
# Brand 2: HGB grid search over 108 configs
# [1/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 1213.170
#     NEW BEST: MAE=1213.170 | params={'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
# [2/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 1216.087
# [3/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 1239.878
# [4/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 1200.339
#     NEW BEST: MAE=1200.339 | params={'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
# [5/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 1236.484
# [6/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 1238.714
# [7/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 1159.199
#     NEW BEST: MAE=1159.199 | params={'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
# [8/108] params: {'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 1216.661
# ...
#     -> MAE (log1p): 943.685
# [37/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 933.058
# [38/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 938.400
# [39/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 950.848
# [40/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 916.717
# [41/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 910.260
# [42/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 934.636
# [43/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 938.946
# [44/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 940.445
# [45/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 964.952
# [46/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 929.066
# [47/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 919.370
# [48/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 933.588
# [49/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 934.173
# [50/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 935.090
# [51/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 938.159
# [52/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 927.669
# [53/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 907.499
#     NEW BEST: MAE=907.499 | params={'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}
# [54/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 917.985
# [55/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.06, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 955.208
# [56/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.06, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 950.440
# [57/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.06, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 956.262
# [58/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.06, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 924.683
# [59/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.06, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 923.932
# [60/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.06, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 948.048
# [61/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 918.735
# [62/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 938.510
# [63/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 949.562
# [64/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 923.352
# [65/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 913.327
# [66/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 922.058
# [67/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.1, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 940.805
# [68/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.1, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 952.052
# [69/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.1, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 984.085
# [70/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.1, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 941.021
# [71/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.1, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 920.714
# [72/108] params: {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.1, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 920.027
# [73/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 939.798
# [74/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 934.183
# [75/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 957.742
# [76/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 921.227
# [77/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 921.774
# [78/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.03, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 929.704
# [79/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 944.741
# [80/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 948.795
# [81/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 971.274
# [82/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 926.824
# [83/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 924.287
# [84/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.03, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 937.342
# [85/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 928.177
# [86/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 943.911
# [87/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 952.576
# [88/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 917.454
# [89/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 914.429
# [90/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 922.769
# [91/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.06, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 942.123
# [92/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.06, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 944.327
# [93/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.06, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 959.516
# [94/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.06, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 926.562
# [95/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.06, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 912.958
# [96/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.06, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 945.252
# [97/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 922.535
# [98/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 938.693
# [99/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 942.796
# [100/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 911.969
# [101/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 917.268
# [102/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 920.833
# [103/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.1, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 935.783
# [104/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.1, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 942.502
# [105/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.1, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 965.272
# [106/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.1, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
#     -> MAE (log1p): 929.257
# [107/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.1, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}
#     -> MAE (log1p): 922.202
# [108/108] params: {'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.1, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 50}
#     -> MAE (log1p): 941.222
#
# ===== FINAL BEST HGB PER BRAND =====
# Brand 0: MAE=906.985 | params={'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
# Brand 1: MAE=1766.397 | params={'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
# Brand 2: MAE=1144.058 | params={'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.1, 'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
# Brand 3: MAE=729.579 | params={'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
# Brand 4: MAE=1501.458 | params={'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
# Brand 5: MAE=1668.124 | params={'early_stopping': True, 'l2_regularization': 0.02, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
# Brand 6: MAE=797.314 | params={'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 10}
# Brand 7: MAE=1014.367 | params={'early_stopping': True, 'l2_regularization': 0.1, 'learning_rate': 0.06, 'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 10}
# Brand 8: MAE=907.499 | params={'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.06, 'max_bins': 128, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30}

# %% [markdown]
# Help: hardcode of the result to calculate quicker

# %%
# best_params_per_brand_hgb = 
[
    # Brand 0
    {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.06,
     'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30,
     'n_iter_no_change': 50, 'validation_fraction': 0.1},

    # Brand 1
    {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.06,
     'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30,
     'n_iter_no_change': 50, 'validation_fraction': 0.1},

    # Brand 2
    {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.06,
     'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30,
     'n_iter_no_change': 50, 'validation_fraction': 0.1},

    # Brand 3
    {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.06,
     'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30,
     'n_iter_no_change': 50, 'validation_fraction': 0.1},

    # Brand 4
    {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.06,
     'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 50,
     'n_iter_no_change': 50, 'validation_fraction': 0.1},

    # Brand 5
    {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.06,
     'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30,
     'n_iter_no_change': 50, 'validation_fraction': 0.1},

    # Brand 6
    {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.06,
     'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30,
     'n_iter_no_change': 50, 'validation_fraction': 0.1},

    # Brand 7
    {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.06,
     'max_bins': 255, 'max_depth': 6, 'max_iter': 4000, 'min_samples_leaf': 30,
     'n_iter_no_change': 50, 'validation_fraction': 0.1},

    # Brand 8
    {'early_stopping': True, 'l2_regularization': 0.05, 'learning_rate': 0.06,
     'max_bins': 255, 'max_depth': 8, 'max_iter': 4000, 'min_samples_leaf': 30,
     'n_iter_no_change': 50, 'validation_fraction': 0.1},
]
# Out:
# [{'early_stopping': True,
#   'l2_regularization': 0.05,
#   'learning_rate': 0.06,
#   'max_bins': 255,
#   'max_depth': 8,
#   'max_iter': 4000,
#   'min_samples_leaf': 30,
#   'n_iter_no_change': 50,
#   'validation_fraction': 0.1},
#  {'early_stopping': True,
#   'l2_regularization': 0.05,
#   'learning_rate': 0.06,
#   'max_bins': 255,
#   'max_depth': 8,
#   'max_iter': 4000,
#   'min_samples_leaf': 30,
#   'n_iter_no_change': 50,
#   'validation_fraction': 0.1},
#  {'early_stopping': True,
#   'l2_regularization': 0.05,
#   'learning_rate': 0.06,
#   'max_bins': 255,
#   'max_depth': 8,
#   'max_iter': 4000,
#   'min_samples_leaf': 30,
#   'n_iter_no_change': 50,
#   'validation_fraction': 0.1},
#  {'early_stopping': True,
#   'l2_regularization': 0.05,
#   'learning_rate': 0.06,
#   'max_bins': 255,
#   'max_depth': 6,
#   'max_iter': 4000,
#   'min_samples_leaf': 30,
#   'n_iter_no_change': 50,
#   'validation_fraction': 0.1},
#  {'early_stopping': True,
#   'l2_regularization': 0.05,
#   'learning_rate': 0.06,
#   'max_bins': 255,
#   'max_depth': 6,
#   'max_iter': 4000,
#   'min_samples_leaf': 50,
#   'n_iter_no_change': 50,
#   'validation_fraction': 0.1},
#  {'early_stopping': True,
#   'l2_regularization': 0.05,
#   'learning_rate': 0.06,
#   'max_bins': 255,
#   'max_depth': 8,
#   'max_iter': 4000,
#   'min_samples_leaf': 30,
#   'n_iter_no_change': 50,
#   'validation_fraction': 0.1},
#  {'early_stopping': True,
#   'l2_regularization': 0.05,
#   'learning_rate': 0.06,
#   'max_bins': 255,
#   'max_depth': 8,
#   'max_iter': 4000,
#   'min_samples_leaf': 30,
#   'n_iter_no_change': 50,
#   'validation_fraction': 0.1},
#  {'early_stopping': True,
#   'l2_regularization': 0.05,
#   'learning_rate': 0.06,
#   'max_bins': 255,
#   'max_depth': 6,
#   'max_iter': 4000,
#   'min_samples_leaf': 30,
#   'n_iter_no_change': 50,
#   'validation_fraction': 0.1},
#  {'early_stopping': True,
#   'l2_regularization': 0.05,
#   'learning_rate': 0.06,
#   'max_bins': 255,
#   'max_depth': 8,
#   'max_iter': 4000,
#   'min_samples_leaf': 30,
#   'n_iter_no_change': 50,
#   'validation_fraction': 0.1}]

# %% [markdown]
# Then we use the found parameters for the algorithm to predict the prices of our test data. We therefore also log transform the target.

# %%
test_pred_list_hgb = []
test_pred_list_hgb_log = []
metrics_per_brand_hgb = []

val_pred_list_hgb_log = []
val_pred_list_hgb = []

for i in range(len(train_x_list)):

    y_tr = train_y_list[i]
    y_va = val_y_list[i]
    if isinstance(y_tr, pd.DataFrame): y_tr = y_tr.iloc[:, 0]
    if isinstance(y_va, pd.DataFrame): y_va = y_va.iloc[:, 0]

    # val fit + preds
    params_hgb = best_params_per_brand_hgb[i].copy()
    params_hgb['loss'] = 'absolute_error'

    hgb = HistGradientBoostingRegressor(**params_hgb, random_state=42)
    hgb.fit(train_x_list[i], np.log1p(y_tr))

    pred_va_log = hgb.predict(val_x_list[i])
    pred_va = np.expm1(pred_va_log)

    val_pred_list_hgb_log.append(pd.Series(pred_va_log, index=val_x_list[i].index, name="price_log"))
    val_pred_list_hgb.append(pd.Series(pred_va, index=val_x_list[i].index, name="price"))  # optional

    mae   = mean_absolute_error(y_va, pred_va)
    rmse  = np.sqrt(mean_squared_error(y_va, pred_va))
    r2    = r2_score(y_va, pred_va)
    medae = median_absolute_error(y_va, pred_va)

    metrics_per_brand_hgb.append({"brand_idx": i, "mae": mae, "rmse": rmse, "r2": r2, "medae": medae})

    print(f"Brand {i}: val MAE={mae:.3f}, RMSE={rmse:.3f}, R2={r2:.3f}, MedAE={medae:.3f}")

    # final train+val -> test
    x_trainval = pd.concat([train_x_list[i], val_x_list[i]], axis=0)
    y_trainval = pd.concat([y_tr, y_va], axis=0)

    params_hgb_final = best_params_per_brand_hgb[i].copy()
    params_hgb_final['loss'] = 'absolute_error'

    hgb_final = HistGradientBoostingRegressor(**params_hgb_final, random_state=42)
    hgb_final.fit(x_trainval, np.log1p(y_trainval))

    pred_te_log = hgb_final.predict(test_x_list[i])
    pred_te = np.expm1(pred_te_log)

    test_pred_list_hgb.append(pd.Series(pred_te, index=test_x_list[i].index, name="price"))
    test_pred_list_hgb_log.append(pd.Series(pred_te_log, index=test_x_list[i].index, name="price_log"))
metrics_hgb = pd.DataFrame(metrics_per_brand_hgb)
# Out:
# Brand 0: val MAE=923.777, RMSE=1444.797, R2=0.915, MedAE=663.419
# Brand 1: val MAE=1881.848, RMSE=3827.998, R2=0.861, MedAE=1233.576
# Brand 2: val MAE=1204.064, RMSE=2006.919, R2=0.933, MedAE=737.901
# Brand 3: val MAE=750.276, RMSE=1183.151, R2=0.888, MedAE=529.408
# Brand 4: val MAE=1551.295, RMSE=2297.161, R2=0.954, MedAE=1083.832
# Brand 5: val MAE=1700.238, RMSE=2714.043, R2=0.945, MedAE=1129.602
# Brand 6: val MAE=832.813, RMSE=1396.161, R2=0.949, MedAE=536.943
# Brand 7: val MAE=1081.282, RMSE=1608.622, R2=0.933, MedAE=769.031
# Brand 8: val MAE=943.538, RMSE=1498.637, R2=0.938, MedAE=586.483

# %% [markdown]
# After that we build the submission.

# %%
# put all brand predictions back together
test_pred_list_hgb = pd.concat(test_pred_list_hgb).sort_index()

# build submission
submission = test_pred_list_hgb.reset_index()
submission.columns = ["CarID", "price"]
submission.to_csv("submission.csv", index=False)

print(submission.head())
print("total preds:", len(submission))
# Out:
#    CarID         price
# 0  75973  10333.031103
# 1  75974  21678.791206
# 2  75975  29728.834555
# 3  75976  26816.123341
# 4  75977  15811.706624
# total preds: 32567

# %% [markdown]
# After that we upload the submission in the submission folder, by the suffix _hgbr we know which model it was.

# %%
# Save
sub_dir = os.path.join(data_dir, "submissions")
os.makedirs(sub_dir, exist_ok=True)
ts = datetime.now().strftime("%Y%m%d_%H%M")
sub_path = os.path.join(sub_dir, f"30_submission_{ts}_hgbr.csv")
submission.to_csv(sub_path, index=False)

print(f"Submission saved to: {sub_path}")
display(submission.head(10))
# Out:
# Submission saved to: ../data/submissions\30_submission_20251215_1957_hgbr.csv
#    CarID         price
# 0  75973  10333.031103
# 1  75974  21678.791206
# 2  75975  29728.834555
# 3  75976  26816.123341
# 4  75977  15811.706624
# 5  75978  21911.663822
# 6  75979  34764.908612
# 7  75980  26423.547953
# 8  75981  15185.905950
# 9  75982  24825.922992

# %% [markdown]
# ## 9.4 Hybrid Model (Extra Tree Regressor * 0,6 + High Gradient Boosting * 0,4)

# %% [markdown]
# For the hybrid model we take the predictions of both models, apply their wheigts and add them toegther. We then create the submission.

# %%
w = 0.6
metrics_per_brand_blend = []

for i in range(len(val_y_list)):
    y_va = val_y_list[i]
    if isinstance(y_va, pd.DataFrame): y_va = y_va.iloc[:, 0]

    pred_et_va_log  = val_pred_list_et_log[i].copy()
    pred_hgb_va_log = val_pred_list_hgb_log[i].copy()

    # align indices
    y_va_s = pd.Series(y_va.values, index=y_va.index)
    y_va_s.index = y_va_s.index.astype(int)

    pred_et_va_log.index  = pred_et_va_log.index.astype(int)
    pred_hgb_va_log.index = pred_hgb_va_log.index.astype(int)

    y_va_s = y_va_s.sort_index()
    pred_et_va_log  = pred_et_va_log.sort_index()
    pred_hgb_va_log = pred_hgb_va_log.sort_index()

    common_idx = y_va_s.index.intersection(pred_et_va_log.index).intersection(pred_hgb_va_log.index)

    # blend in log-space -> back to original
    pred_blend_va = np.expm1(
        w * pred_et_va_log.loc[common_idx] + (1 - w) * pred_hgb_va_log.loc[common_idx]
    )

    y_true = y_va_s.loc[common_idx]

    mae   = mean_absolute_error(y_true, pred_blend_va)
    rmse  = np.sqrt(mean_squared_error(y_true, pred_blend_va))
    r2    = r2_score(y_true, pred_blend_va)
    medae = median_absolute_error(y_true, pred_blend_va)

    metrics_per_brand_blend.append({
        "brand_idx": i,
        "mae": mae,
        "rmse": rmse,
        "r2": r2,
        "medae": medae,
    })

metrics_blend = pd.DataFrame(metrics_per_brand_blend)

# %%
test_pred_list_final = []

w = 0.6  # ET-Gewicht in log-space, HGB = 1-w

for i in range(len(test_pred_list_et_log)):
    pred_et_log  = test_pred_list_et_log[i].copy()
    pred_hgb_log = test_pred_list_hgb_log[i].copy()

    # Indizes alignen
    pred_et_log.index  = pred_et_log.index.astype(int)
    pred_hgb_log.index = pred_hgb_log.index.astype(int)

    pred_et_log  = pred_et_log.sort_index()
    pred_hgb_log = pred_hgb_log.sort_index()

    common_idx = pred_et_log.index.intersection(pred_hgb_log.index)

    # log-space blend -> zurück in Originalskala
    pred_final = np.expm1(
        w * pred_et_log.loc[common_idx] + (1 - w) * pred_hgb_log.loc[common_idx]
    )

    test_pred_list_final.append(pd.Series(pred_final, index=common_idx))

test_pred_all = pd.concat(test_pred_list_final).sort_index()

submission = test_pred_all.reset_index()
submission.columns = ["CarID", "price"]

print(submission.head())
print("total preds:", len(submission))
print("n_nans:", test_pred_all.isna().sum())
# Out:
#    CarID         price
# 0  75973   9960.856027
# 1  75974  21538.285325
# 2  75975  29807.210327
# 3  75976  26790.116062
# 4  75977  15084.185466
# total preds: 32567
# n_nans: 0

# %% [markdown]
# After that we upload the submission in the submission folder, by the suffix _hybrid we know which model it was.

# %%
# Save
sub_dir = os.path.join(data_dir, "submissions")
os.makedirs(sub_dir, exist_ok=True)
ts = datetime.now().strftime("%Y%m%d_%H%M")
sub_path = os.path.join(sub_dir, f"30_submission_{ts}_hybrid.csv")
submission.to_csv(sub_path, index=False)

print(f"Submission saved to: {sub_path}")
display(submission.head(10))
# Out:
# Submission saved to: ../data/submissions\30_submission_20251215_1957_hybrid.csv
#    CarID         price
# 0  75973   9960.856027
# 1  75974  21538.285325
# 2  75975  29807.210327
# 3  75976  26790.116062
# 4  75977  15084.185466
# 5  75978  22304.600450
# 6  75979  34054.943601
# 7  75980  26272.693794
# 8  75981  15722.221751
# 9  75982  24819.142690

# %% [markdown]
# # 10. Evaluation

# %%
test_pred_list_et = []
train_mae_list_et = []
val_mae_list_et = []

train_weights = []   # sample counts per brand (train)
val_weights = []     # sample counts per brand (val)

for i in range(len(train_x_list)):
    X_tr = train_x_list[i]
    X_va = val_x_list[i]
    X_te = test_x_list[i]

    y_tr = train_y_list[i]
    y_va = val_y_list[i]

    # falls y DataFrame -> Series
    if isinstance(y_tr, pd.DataFrame): y_tr = y_tr.iloc[:, 0]
    if isinstance(y_va, pd.DataFrame): y_va = y_va.iloc[:, 0]

    # weights = amount of samples
    train_weights.append(len(y_tr))
    val_weights.append(len(y_va))

    # ====== 1) TRAIN fit -> train + val MAE ======
    et_val = ExtraTreesRegressor(
        **best_params_per_brand_et[i],
        random_state=42,
        n_jobs=-1
    )

    et_val.fit(X_tr, np.log1p(y_tr))

    # train MAE
    pred_tr = np.expm1(et_val.predict(X_tr))
    mae_tr = mean_absolute_error(y_tr, pred_tr)
    train_mae_list_et.append(mae_tr)

    # val MAE
    pred_va = np.expm1(et_val.predict(X_va))
    mae_va = mean_absolute_error(y_va, pred_va)
    val_mae_list_et.append(mae_va)

    print(f"Brand {i}: train MAE = {mae_tr:.3f} | val MAE = {mae_va:.3f}")

    # ====== 2) FINAL fit (train+val) -> test preds ======
    x_trainval = pd.concat([X_tr, X_va], axis=0)
    y_trainval = pd.concat([y_tr, y_va], axis=0)

    et_final = ExtraTreesRegressor(
        **best_params_per_brand_et[i],
        random_state=42,
        n_jobs=-1
    )
    et_final.fit(x_trainval, np.log1p(y_trainval))
    pred_te = np.expm1(et_final.predict(X_te))

    test_pred_list_et.append(pd.Series(pred_te, index=X_te.index, name="price"))

# ===== weighted averages =====
train_weights = np.array(train_weights, dtype=float)
val_weights   = np.array(val_weights, dtype=float)

weighted_train_mae = np.sum(train_weights * np.array(train_mae_list_et)) / np.sum(train_weights)
weighted_val_mae   = np.sum(val_weights   * np.array(val_mae_list_et))   / np.sum(val_weights)

print("\n=== AVERAGES ===")
print(f"Avg train MAE (weighted):    {weighted_train_mae:.3f}")
print(f"Avg val MAE   (weighted):    {weighted_val_mae:.3f}")
# Out:
# Brand 0: train MAE = 513.078 | val MAE = 920.960
# Brand 1: train MAE = 608.164 | val MAE = 1704.906
# Brand 2: train MAE = 584.586 | val MAE = 1158.262
# Brand 3: train MAE = 491.590 | val MAE = 748.455
# Brand 4: train MAE = 480.324 | val MAE = 1493.215
# Brand 5: train MAE = 752.681 | val MAE = 1674.251
# Brand 6: train MAE = 555.560 | val MAE = 796.868
# Brand 7: train MAE = 576.953 | val MAE = 1044.596
# Brand 8: train MAE = 474.482 | val MAE = 853.111
#
# === AVERAGES ===
# Avg train MAE (weighted):    560.162
# Avg val MAE   (weighted):    1182.451

# %%
brand_names = ["Ford", "Mercedes-Benz", "Volkswagen", "Opel", "BMW",
               "Audi", "Toyota", "Škoda", "Hyundai"]

stats = []

for name, y in zip(brand_names, train_y_list):
    # if y is a DataFrame -> take first column
    if isinstance(y, pd.DataFrame):
        y = y.iloc[:, 0]
    # now y should be a Series
    stats.append({
        "Brand": name,
        "count": int(y.shape[0]),
        "avg_price": float(y.mean()),
        "median_price": float(y.median())
    })

stats_df = pd.DataFrame(stats).sort_values("avg_price", ascending=False)

print(stats_df.to_string(index=False))
# Out:
#         Brand  count    avg_price  median_price
# Mercedes-Benz   9913 24559.304751       22691.0
#          Audi   6226 22934.500964       20461.0
#           BMW   6283 22750.429731       20298.0
#    Volkswagen   8835 16900.218563       15698.0
#         Škoda   3649 14189.845163       12998.0
#       Hyundai   2837 12770.424744       11995.0
#          Ford  13658 12565.646800       11700.0
#        Toyota   3938 12482.501270       10698.0
#          Opel   7957 10345.071132        9998.0

# %%
metrics_et_cmp = metrics_et.rename(columns={
    "mae": "et_mae", "rmse": "et_rmse", "r2": "et_r2", "medae": "et_medae"
})
metrics_rf_cmp = metrics_rf.rename(columns={
    "mae": "rf_mae", "rmse": "rf_rmse", "r2": "rf_r2", "medae": "rf_medae"
})
metrics_hgb_cmp = metrics_hgb.rename(columns={
    "mae": "hgb_mae", "rmse": "hgb_rmse", "r2": "hgb_r2", "medae": "hgb_medae"
})
metrics_blend_cmp = metrics_blend.rename(columns={
    "mae": "blend_mae", "rmse": "blend_rmse", "r2": "blend_r2", "medae": "blend_medae"
})

# --- merge zu einer Vergleichstabelle ---
compare_df = (
    metrics_et_cmp.merge(metrics_rf_cmp, on="brand_idx", how="outer")
                 .merge(metrics_hgb_cmp, on="brand_idx", how="outer")
                 .merge(metrics_blend_cmp, on="brand_idx", how="outer")
                 .sort_values("brand_idx")
                 .reset_index(drop=True)
)

# --- optional: Blend vs best single model (Errors: kleiner besser, R2: größer besser) ---
compare_df["blend_vs_best_single_mae"]   = compare_df["blend_mae"]   - compare_df[["et_mae","rf_mae","hgb_mae"]].min(axis=1)
compare_df["blend_vs_best_single_rmse"]  = compare_df["blend_rmse"]  - compare_df[["et_rmse","rf_rmse","hgb_rmse"]].min(axis=1)
compare_df["blend_vs_best_single_medae"] = compare_df["blend_medae"] - compare_df[["et_medae","rf_medae","hgb_medae"]].min(axis=1)
compare_df["blend_vs_best_single_r2"]    = compare_df["blend_r2"]    - compare_df[["et_r2","rf_r2","hgb_r2"]].max(axis=1)

# --- optional: Mean-Zeile am Ende ---
mean_row = compare_df.drop(columns=["brand_idx"]).mean(numeric_only=True).to_frame().T
mean_row.insert(0, "brand_idx", "MEAN")
compare_df = pd.concat([compare_df, mean_row], ignore_index=True)

compare_df
# Out:
#   brand_idx       et_mae      et_rmse     et_r2     et_medae       rf_mae  \
# 0         0   910.026465  1454.732097  0.913356   648.371034   909.259067
# 1         1  1686.936811  2726.501489  0.929277  1099.089957  1739.100228
# 2         2  1151.333657  1810.748027  0.945362   725.276510  1162.735681
# 3         3   744.427024  1172.906305  0.890092   526.220305   750.809714
# 4         4  1485.634655  2267.478591  0.955519   966.969429  1480.213924
# 5         5  1667.793810  2879.923020  0.937873  1101.485452  1697.731069
# 6         6   806.198462  1364.429387  0.951527   528.400952   813.815163
# 7         7  1032.395493  1474.797984  0.943303   734.217130  1025.368157
# 8         8   855.082267  1317.312656  0.952126   565.312672   879.968619
# 9      MEAN  1148.869849  1829.869951  0.935382   766.149271  1162.111291
#
#        rf_rmse     rf_r2     rf_medae      hgb_mae  ...    hgb_r2  \
# 0  1441.542985  0.914920   649.366892   923.777136  ...  0.914535
# 1  3269.648224  0.898293  1122.838923  1881.848206  ...  0.860590
# 2  1829.419594  0.944230   715.081723  1204.064020  ...  0.932882
# 3  1167.654825  0.891074   515.978218   750.275522  ...  0.888163
# 4  2221.865846  0.957290   973.082191  1551.294824  ...  0.954346
# 5  2795.114307  0.941478  1136.359851  1700.237603  ...  0.944824
# 6  1342.270310  0.953089   508.673948   832.812873  ...  0.949246
# 7  1451.563999  0.945075   725.985924  1081.281789  ...  0.932547
# 8  1328.294358  0.951325   592.246755   943.538393  ...  0.938040
# 9  1871.930494  0.932975   771.068270  1207.681152  ...  0.923908
#
#      hgb_medae    blend_mae   blend_rmse  blend_r2  blend_medae  \
# 0   663.418961   895.974256  1419.706647  0.917478   636.022548
# 1  1233.575534  1710.152225  3156.576846  0.905206  1108.483817
# 2   737.900701  1135.305695  1806.892806  0.945595   692.216636
# 3   529.408012   733.815963  1156.959581  0.893060   519.464771
# 4  1083.832219  1441.520459  2163.333233  0.959511   968.652411
# 5  1129.602459  1629.227430  2736.381603  0.943912  1057.603123
# 6   536.942610   792.631538  1330.201689  0.953928   526.547638
# 7   769.030683  1024.298772  1482.318662  0.942723   745.143425
# 8   586.483336   861.291283  1339.339923  0.950512   563.460600
# 9   807.799391  1136.024180  1843.523443  0.934658   757.510552
#
#    blend_vs_best_single_mae  blend_vs_best_single_rmse  \
# 0                -13.284812                 -21.836337
# 1                 23.215414                 430.075358
# 2                -16.027962                  -3.855221
# 3                -10.611061                 -10.695244
# 4                -38.693465                 -58.532613
# 5                -38.566380                  22.338602
# 6                -13.566924                 -12.068621
# 7                 -1.069385                  30.754663
# 8                  6.209015                  22.027266
# 9                -11.377284                  44.245317
#
#    blend_vs_best_single_medae  blend_vs_best_single_r2
# 0                  -12.348486                 0.002558
# 1                    9.393860                -0.024071
# 2                  -22.865087                 0.000232
# 3                    3.486553                 0.001986
# 4                    1.682982                 0.002221
# 5                  -43.882329                -0.000912
# 6                   17.873690                 0.000840
# 7                   19.157501                -0.002352
# 8                   -1.852072                -0.001614
# 9                   -3.261488                -0.002346
#
# [10 rows x 21 columns]
