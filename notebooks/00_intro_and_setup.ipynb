# %% [markdown]
# # Cars 4 You: Homework GroupXX
# **Goal:** Predict car prices using machine learning (regression task).
# This notebook introduces the context, datasets, and environment setup.
#
# **Team Members:**
# - Oliver Kain
# - Joao
# - Goncalo
# - Mehmet Karaca
#
# **Deliverable:** Data exploration, preprocessing, feature selection, and first regression benchmark.
# **Deadline:** 03.11.2025 (17:59)
